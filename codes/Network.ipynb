# %%
import networkx as nx
import matplotlib.pyplot as plt

g = nx.Graph()
g.add_node(1)
g.add_node(2)
g.add_node(3)
g.add_node(4)

g.add_edge(1, 2)
g.add_edge(1, 3)
g.add_edge(2, 3)
g.add_edge(2, 4)

f = nx.complete_graph(7)
nx.draw(f)
plt.show()

G = nx.erdos_renyi_graph(5,0.8)
nx.draw(G)
plt.show()


G1 = nx.barabasi_albert_graph(4,2)
nx.draw(G1)
plt.show()

G2 = nx.dense_gnm_random_graph(5, 5)
nx.draw(G2)
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

G= nx.barabasi_albert_graph(400,2)
nx.draw(G, with_labels=True)
plt.show()

print(len(G.edges))
degrees = dict(G.degree())
degree_values = sorted(degrees.values())
histogram = [list(degrees.values()).count(i)/float(nx.number_of_nodes (G)) for i in degree_values]
plt.figure()
plt.plot(degree_values, histogram, 'o')
plt.title('Degree Distribution of erdos renyi graph')
plt.xlabel('Degree')
plt.ylabel('Fraction of Nodes')
plt.xscale('symlog')
plt.yscale('symlog')
plt.show()
# Out:
# 796

# %% [markdown]
# **barabasi_albert_graph**

# %%
import random
import networkx as nx
import matplotlib.pyplot as plt

g = nx.Graph()
n = int(input("Enter number of nodes : "))
e = int(input("Number of edges to attach from a new node to existing nodes : "))

def n_degree(g, x):
  m = []  # storing node degrees
  for j in range(x):
      m.append(g.degree[j])
  return m

t = []
for i in range(n):
  if (i == 0) :
    g.add_node(0)
  elif (i == 1) :
    g.add_node(1)
    g.add_edge(i, i-1)
  elif (i > 1):
    g.add_node(i)
    t = n_degree(g,i)
    un = t[:]
    g.add_edge(i,t.index(max(un)))
    un.remove(max(un))
    if i > e-1:
      for k in range(1,e):
        g.add_edge(i,t.index(max(un)))
        un.remove(max(un))

nx.draw(g , with_labels=True)
plt.show()
print(len(g.edges))

degrees = dict(G.degree())
degree_values = sorted(degrees.values())
histogram = [list(degrees.values()).count(i)/float(nx.number_of_nodes (G)) for i in degree_values]
plt.figure()
plt.plot(degree_values, histogram, 'o')
plt.title('Degree Distribution of erdos renyi graph')
plt.xlabel('Degree')
plt.ylabel('Fraction of Nodes')
plt.xscale('symlog')
plt.yscale('symlog')
plt.show()
# Out:
# Enter number of nodes : 400
# Number of edges to attach from a new node to existing nodes : 2
# 796

# %%
import networkx as nx
import matplotlib.pyplot as plt

G=nx.erdos_renyi_graph(400,0.2)
nx.draw(G, with_labels=True)
plt.show()

print(len(G.edges))

degrees = dict(G.degree())
degree_values = sorted(degrees.values())
histogram = [list(degrees.values()).count(i)/float(nx.number_of_nodes (G)) for i in degree_values]

plt.figure()
plt.plot(degree_values, histogram, 'o')
plt.title('Degree Distribution of erdos renyi graph')
plt.xlabel('Degree')
plt.ylabel('Fraction of Nodes')
plt.xscale('symlog')
plt.yscale('symlog')
plt.show()
# Out:
# 15868

# %%
import random
import networkx as nx
import matplotlib.pyplot as plt
import math
import numpy as np
np.set_printoptions(precision = 3)
g = nx.Graph()
n = int(input("Enter number of nodes : "))
e = float(input("Probability for edge creation : "))

A_prob = np.random.rand(n,n)
A = (A_prob < e).astype('int')

print(A)

g = nx.from_numpy_matrix(A)
nx.draw(g, with_labels=True)
plt.show()

print(len(g.edges))

degrees = dict(g.degree())
degree_values = sorted(degrees.values())
histogram = [list(degrees.values()).count(i)/float(nx.number_of_nodes (g)) for i in degree_values]
plt.figure()
plt.plot(degree_values, histogram, 'o')
plt.title('Degree Distribution of erdos renyi graph')
plt.xlabel('Degree')
plt.ylabel('Fraction of Nodes')
plt.xscale('symlog')
plt.yscale('symlog')
plt.show()

# %%
for i in range(0,n):
  if (i == 0) :
    g.add_node(1)
  elif (i == 1) :
    g.add_edge(i, i-1)
  else :
    l1 = []
    for k in range(0,i):
      l1.append(k)
    p = math.ceil((i*(i-1/2))*e)
    for j in range(0,p):
      if len(l1) == 0:
        break
      b = l1.random.randint(0,len(l1)-1)
      g.add_edge(i ,b)

# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt

G = nx.gnp_random_graph(100, 0.02, seed=10374196)
degree_sequence = sorted((d for n, d in G.degree()), reverse=True)

fig = plt.figure("Degree of a random graph", figsize=(8, 8))
axgrid = fig.add_gridspec(5, 4)
ax2 = fig.add_subplot(axgrid[3:, 2:])
ax2.bar(*np.unique(degree_sequence, return_counts=True))
ax2.set_title("Degree histogram")
ax2.set_xlabel("Degree")
ax2.set_ylabel("# of Nodes")
# Out:
# Text(0, 0.5, '# of Nodes')

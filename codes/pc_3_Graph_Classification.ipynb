# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Install required packages.
import os
import torch
os.environ['TORCH'] = torch.__version__
print(torch.__version__)

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git
# Out:
# 2.0.0+cu118
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 92.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 21.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for torch_geometric (pyproject.toml) ... done

# %% [markdown]
# # Graph Classification with Graph Neural Networks
#
# [Previous: Node Classification with Graph Neural Networks](https://colab.research.google.com/drive/14OvFnAXggxB8vM4e8vSURUp1TaKnovzX)
#
# In this tutorial session we will have a closer look at how to apply **Graph Neural Networks (GNNs) to the task of graph classification**.
# Graph classification refers to the problem of classifiying entire graphs (in contrast to nodes), given a **dataset of graphs**, based on some structural graph properties.
# Here, we want to embed entire graphs, and we want to embed those graphs in such a way so that they are linearly separable given a task at hand.

# %% [markdown]
# ![Screen Shot 2020-08-27 at 13.13.26.png](data:image/png;base64,...)

# %% [markdown]
# The most common task for graph classification is **molecular property prediction**, in which molecules are represented as graphs, and the task may be to infer whether a molecule inhibits HIV virus replication or not.
#
# The TU Dortmund University has collected a wide range of different graph classification datasets, known as the [**TUDatasets**](https://chrsmrrs.github.io/datasets/), which are also accessible via [`torch_geometric.datasets.TUDataset`](https://pytorch-geometric.readthedocs.io/en/latest/modules/datasets.html#torch_geometric.datasets.TUDataset) in PyTorch Geometric.
# Let's load and inspect one of the smaller ones, the **MUTAG dataset**:

# %%
import torch
from torch_geometric.datasets import TUDataset

dataset = TUDataset(root='data/TUDataset', name='Yeast')

print()
print(f'Dataset: {dataset}:')
print('====================')
print(f'Number of graphs: {len(dataset)}')
print(f'Number of features: {dataset.num_features}')
print(f'Number of classes: {dataset.num_classes}')

data = dataset[0]  # Get the first graph object.

print()
print(data)
print('=============================================================')

# Gather some statistics about the first graph.
print(f'Number of nodes: {data.num_nodes}')
print(f'Number of edges: {data.num_edges}')
print(f'Average node degree: {data.num_edges / data.num_nodes:.2f}')
print(f'Has isolated nodes: {data.has_isolated_nodes()}')
print(f'Has self-loops: {data.has_self_loops()}')
print(f'Is undirected: {data.is_undirected()}')
# Out:
# Downloading https://www.chrsmrrs.com/graphkerneldatasets/Yeast.zip
# Extracting data/TUDataset/Yeast/Yeast.zip
# Processing...
# Done!
# Dataset: Yeast(79601):
# ====================
# Number of graphs: 79601
# Number of features: 74
# Number of classes: 2
#
# Data(edge_index=[2, 32], x=[18, 74], edge_attr=[32, 3], y=[1])
# =============================================================
# Number of nodes: 18
# Number of edges: 32
# Average node degree: 1.78
# Has isolated nodes: True
# Has self-loops: False
# Is undirected: True

# %%
#@title Adjacency Matrix
adj = []

for i in range(len(dataset)):
    graph_data = dataset[i]
    node_features = graph_data.x.numpy()
    edge_indices = graph_data.edge_index.numpy()
    num_nodes = node_features.shape[0]
    adj_matrix = np.zeros((num_nodes, num_nodes))
    for i in range(edge_indices.shape[1]):
        src = edge_indices[0, i]
        tgt = edge_indices[1, i]
        adj_matrix[src, tgt] = 1
        adj_matrix[tgt, src] = 1 
    adj.append(adj_matrix)

# %%
#@title Min & Max

Max = []
Min = []

for i in range(len(dataset)):
    node_degrees = np.sum(adj[i], axis=1)
    a = np.max(node_degrees)
    b = np.min(node_degrees)
    Max.append(int(a))
    Min.append(int(b))

# %%
#@title AverageNodeDegree/NumNodes/NumEdges/Labels
graphs = []
avgnodedegree = []
NumNodes = []
NumEdges = []
labels = []

for i in range(len(dataset)):
  graphs.append(i+1)
  avgnodedegree.append(dataset[i].num_edges/dataset[i].num_nodes)
  NumNodes.append(dataset[i].num_nodes)
  NumEdges.append(dataset[i].num_edges)
  labels.append(np.array(dataset[i].y))

# %%
#@title Max_degree Plot
plt.bar(graphs, Max)
plt.xlabel(r'$G_{i}$')
plt.ylabel(r'$k_{max}$')
plt.title('Maximum Node Degrees')
#plt.savefig('QM9_MaximumNodeDegrees.png')
plt.show()

# %%
#@title Min_degree Plot
plt.bar(graphs, Min)
plt.xlabel(r'$G_{i}$')
plt.ylabel(r'$k_{min}$')
plt.title('Minimum Node Degrees')
#plt.savefig('NCI109_MinimumNodeDegrees.png')
plt.show()

# %%
#@title Average_Node_degree Plot
plt.bar(graphs, avgnodedegree)
plt.xlabel(r'$G_{i}$')
plt.ylabel(r'$k_{Avg}$')
plt.title('Average Node Degree')
#plt.savefig('NCI109_AverageNodeDegree.png')
plt.show()

# %%
#@title Number of Nodes Plot
plt.bar(graphs, NumNodes)
plt.xlabel(r'$G_{i}$')
plt.ylabel(r'$N_{i}$')
plt.title('Number of Nodes')
#plt.savefig('NCI109_Number of Nodes.png')
plt.show()

# %%
#@title Number of Edges Plot
plt.bar(graphs, NumEdges)
plt.xlabel(r'$G_{i}$')
plt.ylabel(r'$E_{i}$')
plt.title('Number of Edges')
#plt.savefig('NCI109_Number of Edges.png')
plt.show()

# %%
#@title Labels Plot
plt.plot(labels, NumNodes, 'ro')
plt.xlabel(r'$y_{i}$')
plt.ylabel(r'$N_{i}$')
plt.title('labels')
#plt.savefig('NCI109_labels.png')
plt.show()

# %% [markdown]
# This dataset provides **188 different graphs**, and the task is to classify each graph into **one out of two classes**.
#
# By inspecting the first graph object of the dataset, we can see that it comes with **17 nodes (with 7-dimensional feature vectors)** and **38 edges** (leading to an average node degree of 2.24).
# It also comes with exactly **one graph label** (`y=[1]`), and, in addition to previous datasets, provides addtional **4-dimensional edge features** (`edge_attr=[38, 4]`).
# However, for the sake of simplicity, we will not make use of those.
#
# PyTorch Geometric provides some useful utilities for working with graph datasets, *e.g.*, we can shuffle the dataset and use the first 150 graphs as training graphs, while using the remaining ones for testing:

# %%
torch.manual_seed(12345)
dataset = dataset.shuffle()

train_dataset = dataset[:64000]
test_dataset = dataset[64000:]

print(f'Number of training graphs: {len(train_dataset)}')
print(f'Number of test graphs: {len(test_dataset)}')
# Out:
# Number of training graphs: 64000
# Number of test graphs: 15601

# %% [markdown]
# ## Mini-batching of graphs
#
# Since graphs in graph classification datasets are usually small, a good idea is to **batch the graphs** before inputting them into a Graph Neural Network to guarantee full GPU utilization.
# In the image or language domain, this procedure is typically achieved by **rescaling** or **padding** each example into a set of equally-sized shapes, and examples are then grouped in an additional dimension.
# The length of this dimension is then equal to the number of examples grouped in a mini-batch and is typically referred to as the `batch_size`.
#
# However, for GNNs the two approaches described above are either not feasible or may result in a lot of unnecessary memory consumption.
# Therefore, PyTorch Geometric opts for another approach to achieve parallelization across a number of examples. Here, adjacency matrices are stacked in a diagonal fashion (creating a giant graph that holds multiple isolated subgraphs), and node and target features are simply concatenated in the node dimension:

# %% [markdown]
# ![Screen Shot 2020-08-27 at 13.11.53.png](data:image/png;base64,...)

# %% [markdown]
# This procedure has some crucial advantages over other batching procedures:
#
# 1. GNN operators that rely on a message passing scheme do not need to be modified since messages are not exchanged between two nodes that belong to different graphs.
#
# 2. There is no computational or memory overhead since adjacency matrices are saved in a sparse fashion holding only non-zero entries, *i.e.*, the edges.
#
# PyTorch Geometric automatically takes care of **batching multiple graphs into a single giant graph** with the help of the [`torch_geometric.data.DataLoader`](https://pytorch-geometric.readthedocs.io/en/latest/modules/data.html#torch_geometric.data.DataLoader) class:

# %%
from torch_geometric.loader import DataLoader

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

for step, data in enumerate(train_loader):
    print(f'Step {step + 1}:')
    print('=======')
    print(f'Number of graphs in the current batch: {data.num_graphs}')
    print(data)
    print()
# Out:
# Step 1:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3002], x=[1406, 74], edge_attr=[3002, 3], y=[64], batch=[1406], ptr=[65])
#
# Step 2:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2700], x=[1265, 74], edge_attr=[2700, 3], y=[64], batch=[1265], ptr=[65])
#
# Step 3:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2836], x=[1340, 74], edge_attr=[2836, 3], y=[64], batch=[1340], ptr=[65])
#
# Step 4:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2942], x=[1394, 74], edge_attr=[2942, 3], y=[64], batch=[1394], ptr=[65])
#
# Step 5:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3242], x=[1527, 74], edge_attr=[3242, 3], y=[64], batch=[1527], ptr=[65])
#
# Step 6:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2920], x=[1376, 74], edge_attr=[2920, 3], y=[64], batch=[1376], ptr=[65])
#
# Step 7:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2808], x=[1335, 74], edge_attr=[2808, 3], y=[64], batch=[1335], ptr=[65])
#
# Step 8:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2780], x=[1303, 74], edge_attr=[2780, 3], y=[64], batch=[1303], ptr=[65])
#
# Step 9:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2860], x=[1360, 74], edge_attr=[2860, 3], y=[64], batch=[1360], ptr=[65])
#
# Step 10:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2870], x=[1352, 74], edge_attr=[2870, 3], y=[64], batch=[1352], ptr=[65])
#
# Step 11:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3004], x=[1411, 74], edge_attr=[3004, 3], y=[64], batch=[1411], ptr=[65])
#
# Step 12:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2774], x=[1320, 74], edge_attr=[2774, 3], y=[64], batch=[1320], ptr=[65])
#
# Step 13:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2772], x=[1319, 74], edge_attr=[2772, 3], y=[64], batch=[1319], ptr=[65])
#
# Step 14:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2608], x=[1237, 74], edge_attr=[2608, 3], y=[64], batch=[1237], ptr=[65])
#
# Step 15:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2608], x=[1241, 74], edge_attr=[2608, 3], y=[64], batch=[1241], ptr=[65])
#
# Step 16:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3150], x=[1465, 74], edge_attr=[3150, 3], y=[64], batch=[1465], ptr=[65])
#
# Step 17:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2952], x=[1399, 74], edge_attr=[2952, 3], y=[64], batch=[1399], ptr=[65])
#
# Step 18:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2778], x=[1319, 74], edge_attr=[2778, 3], y=[64], batch=[1319], ptr=[65])
#
# Step 19:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2850], x=[1360, 74], edge_attr=[2850, 3], y=[64], batch=[1360], ptr=[65])
#
# Step 20:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2906], x=[1362, 74], edge_attr=[2906, 3], y=[64], batch=[1362], ptr=[65])
#
# Step 21:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2826], x=[1342, 74], edge_attr=[2826, 3], y=[64], batch=[1342], ptr=[65])
#
# Step 22:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3016], x=[1431, 74], edge_attr=[3016, 3], y=[64], batch=[1431], ptr=[65])
#
# Step 23:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2732], x=[1295, 74], edge_attr=[2732, 3], y=[64], batch=[1295], ptr=[65])
#
# Step 24:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3106], x=[1470, 74], edge_attr=[3106, 3], y=[64], batch=[1470], ptr=[65])
#
# Step 25:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2994], x=[1416, 74], edge_attr=[2994, 3], y=[64], batch=[1416], ptr=[65])
#
# Step 26:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3092], x=[1454, 74], edge_attr=[3092, 3], y=[64], batch=[1454], ptr=[65])
#
# Step 27:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2926], x=[1379, 74], edge_attr=[2926, 3], y=[64], batch=[1379], ptr=[65])
#
# Step 28:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2894], x=[1374, 74], edge_attr=[2894, 3], y=[64], batch=[1374], ptr=[65])
#
# Step 29:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2900], x=[1357, 74], edge_attr=[2900, 3], y=[64], batch=[1357], ptr=[65])
#
# Step 30:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2974], x=[1401, 74], edge_attr=[2974, 3], y=[64], batch=[1401], ptr=[65])
#
# Step 31:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2974], x=[1390, 74], edge_attr=[2974, 3], y=[64], batch=[1390], ptr=[65])
#
# Step 32:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3218], x=[1513, 74], edge_attr=[3218, 3], y=[64], batch=[1513], ptr=[65])
#
# Step 33:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2820], x=[1354, 74], edge_attr=[2820, 3], y=[64], batch=[1354], ptr=[65])
#
# Step 34:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2808], x=[1336, 74], edge_attr=[2808, 3], y=[64], batch=[1336], ptr=[65])
#
# Step 35:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2828], x=[1346, 74], edge_attr=[2828, 3], y=[64], batch=[1346], ptr=[65])
#
# Step 36:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3372], x=[1576, 74], edge_attr=[3372, 3], y=[64], batch=[1576], ptr=[65])
#
# Step 37:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2988], x=[1412, 74], edge_attr=[2988, 3], y=[64], batch=[1412], ptr=[65])
#
# Step 38:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2816], x=[1314, 74], edge_attr=[2816, 3], y=[64], batch=[1314], ptr=[65])
#
# Step 39:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2954], x=[1397, 74], edge_attr=[2954, 3], y=[64], batch=[1397], ptr=[65])
#
# Step 40:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3052], x=[1432, 74], edge_attr=[3052, 3], y=[64], batch=[1432], ptr=[65])
#
# Step 41:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2770], x=[1296, 74], edge_attr=[2770, 3], y=[64], batch=[1296], ptr=[65])
#
# Step 42:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2706], x=[1270, 74], edge_attr=[2706, 3], y=[64], batch=[1270], ptr=[65])
#
# Step 43:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2874], x=[1347, 74], edge_attr=[2874, 3], y=[64], batch=[1347], ptr=[65])
#
# Step 44:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2852], x=[1347, 74], edge_attr=[2852, 3], y=[64], batch=[1347], ptr=[65])
#
# Step 45:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2778], x=[1309, 74], edge_attr=[2778, 3], y=[64], batch=[1309], ptr=[65])
#
# Step 46:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3058], x=[1419, 74], edge_attr=[3058, 3], y=[64], batch=[1419], ptr=[65])
#
# Step 47:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2890], x=[1370, 74], edge_attr=[2890, 3], y=[64], batch=[1370], ptr=[65])
#
# Step 48:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2892], x=[1356, 74], edge_attr=[2892, 3], y=[64], batch=[1356], ptr=[65])
#
# Step 49:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2926], x=[1373, 74], edge_attr=[2926, 3], y=[64], batch=[1373], ptr=[65])
#
# Step 50:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2814], x=[1316, 74], edge_attr=[2814, 3], y=[64], batch=[1316], ptr=[65])
#
# Step 51:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2802], x=[1316, 74], edge_attr=[2802, 3], y=[64], batch=[1316], ptr=[65])
#
# Step 52:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2788], x=[1301, 74], edge_attr=[2788, 3], y=[64], batch=[1301], ptr=[65])
#
# Step 53:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2810], x=[1341, 74], edge_attr=[2810, 3], y=[64], batch=[1341], ptr=[65])
#
# Step 54:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3050], x=[1424, 74], edge_attr=[3050, 3], y=[64], batch=[1424], ptr=[65])
#
# Step 55:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3084], x=[1439, 74], edge_attr=[3084, 3], y=[64], batch=[1439], ptr=[65])
#
# Step 56:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2864], x=[1341, 74], edge_attr=[2864, 3], y=[64], batch=[1341], ptr=[65])
#
# Step 57:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2730], x=[1304, 74], edge_attr=[2730, 3], y=[64], batch=[1304], ptr=[65])
#
# Step 58:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3042], x=[1429, 74], edge_attr=[3042, 3], y=[64], batch=[1429], ptr=[65])
#
# Step 59:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2884], x=[1367, 74], edge_attr=[2884, 3], y=[64], batch=[1367], ptr=[65])
#
# Step 60:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2962], x=[1418, 74], edge_attr=[2962, 3], y=[64], batch=[1418], ptr=[65])
#
# Step 61:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3008], x=[1406, 74], edge_attr=[3008, 3], y=[64], batch=[1406], ptr=[65])
#
# Step 62:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2870], x=[1358, 74], edge_attr=[2870, 3], y=[64], batch=[1358], ptr=[65])
#
# Step 63:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3000], x=[1422, 74], edge_attr=[3000, 3], y=[64], batch=[1422], ptr=[65])
#
# Step 64:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2758], x=[1303, 74], edge_attr=[2758, 3], y=[64], batch=[1303], ptr=[65])
#
# Step 65:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2984], x=[1395, 74], edge_attr=[2984, 3], y=[64], batch=[1395], ptr=[65])
#
# Step 66:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2908], x=[1372, 74], edge_attr=[2908, 3], y=[64], batch=[1372], ptr=[65])
#
# Step 67:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2718], x=[1296, 74], edge_attr=[2718, 3], y=[64], batch=[1296], ptr=[65])
#
# Step 68:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2846], x=[1337, 74], edge_attr=[2846, 3], y=[64], batch=[1337], ptr=[65])
#
# Step 69:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2930], x=[1388, 74], edge_attr=[2930, 3], y=[64], batch=[1388], ptr=[65])
#
# Step 70:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3160], x=[1481, 74], edge_attr=[3160, 3], y=[64], batch=[1481], ptr=[65])
#
# Step 71:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2638], x=[1245, 74], edge_attr=[2638, 3], y=[64], batch=[1245], ptr=[65])
#
# Step 72:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2880], x=[1377, 74], edge_attr=[2880, 3], y=[64], batch=[1377], ptr=[65])
#
# Step 73:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2506], x=[1196, 74], edge_attr=[2506, 3], y=[64], batch=[1196], ptr=[65])
#
# Step 74:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2926], x=[1380, 74], edge_attr=[2926, 3], y=[64], batch=[1380], ptr=[65])
#
# Step 75:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3198], x=[1496, 74], edge_attr=[3198, 3], y=[64], batch=[1496], ptr=[65])
#
# Step 76:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2938], x=[1383, 74], edge_attr=[2938, 3], y=[64], batch=[1383], ptr=[65])
#
# Step 77:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3140], x=[1496, 74], edge_attr=[3140, 3], y=[64], batch=[1496], ptr=[65])
#
# Step 78:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2764], x=[1312, 74], edge_attr=[2764, 3], y=[64], batch=[1312], ptr=[65])
#
# Step 79:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2892], x=[1372, 74], edge_attr=[2892, 3], y=[64], batch=[1372], ptr=[65])
#
# Step 80:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2590], x=[1232, 74], edge_attr=[2590, 3], y=[64], batch=[1232], ptr=[65])
#
# Step 81:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2682], x=[1269, 74], edge_attr=[2682, 3], y=[64], batch=[1269], ptr=[65])
#
# Step 82:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2780], x=[1313, 74], edge_attr=[2780, 3], y=[64], batch=[1313], ptr=[65])
#
# Step 83:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2692], x=[1267, 74], edge_attr=[2692, 3], y=[64], batch=[1267], ptr=[65])
#
# Step 84:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2958], x=[1385, 74], edge_attr=[2958, 3], y=[64], batch=[1385], ptr=[65])
#
# Step 85:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2996], x=[1402, 74], edge_attr=[2996, 3], y=[64], batch=[1402], ptr=[65])
#
# Step 86:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2882], x=[1357, 74], edge_attr=[2882, 3], y=[64], batch=[1357], ptr=[65])
#
# Step 87:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2818], x=[1348, 74], edge_attr=[2818, 3], y=[64], batch=[1348], ptr=[65])
#
# Step 88:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3004], x=[1404, 74], edge_attr=[3004, 3], y=[64], batch=[1404], ptr=[65])
#
# Step 89:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3244], x=[1522, 74], edge_attr=[3244, 3], y=[64], batch=[1522], ptr=[65])
#
# Step 90:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2994], x=[1414, 74], edge_attr=[2994, 3], y=[64], batch=[1414], ptr=[65])
#
# Step 91:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2956], x=[1395, 74], edge_attr=[2956, 3], y=[64], batch=[1395], ptr=[65])
#
# Step 92:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2992], x=[1388, 74], edge_attr=[2992, 3], y=[64], batch=[1388], ptr=[65])
#
# Step 93:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2886], x=[1344, 74], edge_attr=[2886, 3], y=[64], batch=[1344], ptr=[65])
#
# Step 94:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3092], x=[1462, 74], edge_attr=[3092, 3], y=[64], batch=[1462], ptr=[65])
#
# Step 95:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2950], x=[1387, 74], edge_attr=[2950, 3], y=[64], batch=[1387], ptr=[65])
#
# Step 96:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2696], x=[1288, 74], edge_attr=[2696, 3], y=[64], batch=[1288], ptr=[65])
#
# Step 97:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2872], x=[1341, 74], edge_attr=[2872, 3], y=[64], batch=[1341], ptr=[65])
#
# Step 98:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2924], x=[1391, 74], edge_attr=[2924, 3], y=[64], batch=[1391], ptr=[65])
#
# Step 99:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3216], x=[1510, 74], edge_attr=[3216, 3], y=[64], batch=[1510], ptr=[65])
#
# Step 100:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2990], x=[1406, 74], edge_attr=[2990, 3], y=[64], batch=[1406], ptr=[65])
#
# Step 101:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3216], x=[1514, 74], edge_attr=[3216, 3], y=[64], batch=[1514], ptr=[65])
#
# Step 102:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2928], x=[1379, 74], edge_attr=[2928, 3], y=[64], batch=[1379], ptr=[65])
#
# Step 103:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2822], x=[1339, 74], edge_attr=[2822, 3], y=[64], batch=[1339], ptr=[65])
#
# Step 104:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2620], x=[1249, 74], edge_attr=[2620, 3], y=[64], batch=[1249], ptr=[65])
#
# Step 105:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3022], x=[1420, 74], edge_attr=[3022, 3], y=[64], batch=[1420], ptr=[65])
#
# Step 106:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2904], x=[1361, 74], edge_attr=[2904, 3], y=[64], batch=[1361], ptr=[65])
#
# Step 107:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2820], x=[1327, 74], edge_attr=[2820, 3], y=[64], batch=[1327], ptr=[65])
#
# Step 108:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2836], x=[1334, 74], edge_attr=[2836, 3], y=[64], batch=[1334], ptr=[65])
#
# Step 109:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3088], x=[1450, 74], edge_attr=[3088, 3], y=[64], batch=[1450], ptr=[65])
#
# Step 110:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2790], x=[1309, 74], edge_attr=[2790, 3], y=[64], batch=[1309], ptr=[65])
#
# Step 111:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3002], x=[1401, 74], edge_attr=[3002, 3], y=[64], batch=[1401], ptr=[65])
#
# Step 112:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3054], x=[1431, 74], edge_attr=[3054, 3], y=[64], batch=[1431], ptr=[65])
#
# Step 113:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3246], x=[1538, 74], edge_attr=[3246, 3], y=[64], batch=[1538], ptr=[65])
#
# Step 114:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2972], x=[1391, 74], edge_attr=[2972, 3], y=[64], batch=[1391], ptr=[65])
#
# Step 115:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2962], x=[1400, 74], edge_attr=[2962, 3], y=[64], batch=[1400], ptr=[65])
#
# Step 116:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3032], x=[1424, 74], edge_attr=[3032, 3], y=[64], batch=[1424], ptr=[65])
#
# Step 117:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2954], x=[1393, 74], edge_attr=[2954, 3], y=[64], batch=[1393], ptr=[65])
#
# Step 118:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2992], x=[1397, 74], edge_attr=[2992, 3], y=[64], batch=[1397], ptr=[65])
#
# Step 119:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2878], x=[1359, 74], edge_attr=[2878, 3], y=[64], batch=[1359], ptr=[65])
#
# Step 120:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2992], x=[1395, 74], edge_attr=[2992, 3], y=[64], batch=[1395], ptr=[65])
#
# Step 121:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2938], x=[1390, 74], edge_attr=[2938, 3], y=[64], batch=[1390], ptr=[65])
#
# Step 122:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2792], x=[1316, 74], edge_attr=[2792, 3], y=[64], batch=[1316], ptr=[65])
#
# Step 123:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3112], x=[1473, 74], edge_attr=[3112, 3], y=[64], batch=[1473], ptr=[65])
#
# Step 124:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2822], x=[1340, 74], edge_attr=[2822, 3], y=[64], batch=[1340], ptr=[65])
#
# Step 125:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2966], x=[1393, 74], edge_attr=[2966, 3], y=[64], batch=[1393], ptr=[65])
#
# Step 126:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2768], x=[1317, 74], edge_attr=[2768, 3], y=[64], batch=[1317], ptr=[65])
#
# Step 127:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2584], x=[1225, 74], edge_attr=[2584, 3], y=[64], batch=[1225], ptr=[65])
#
# Step 128:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3224], x=[1509, 74], edge_attr=[3224, 3], y=[64], batch=[1509], ptr=[65])
#
# Step 129:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2782], x=[1331, 74], edge_attr=[2782, 3], y=[64], batch=[1331], ptr=[65])
#
# Step 130:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2866], x=[1348, 74], edge_attr=[2866, 3], y=[64], batch=[1348], ptr=[65])
#
# Step 131:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2972], x=[1392, 74], edge_attr=[2972, 3], y=[64], batch=[1392], ptr=[65])
#
# Step 132:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2758], x=[1312, 74], edge_attr=[2758, 3], y=[64], batch=[1312], ptr=[65])
#
# Step 133:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2762], x=[1312, 74], edge_attr=[2762, 3], y=[64], batch=[1312], ptr=[65])
#
# Step 134:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2842], x=[1341, 74], edge_attr=[2842, 3], y=[64], batch=[1341], ptr=[65])
#
# Step 135:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2676], x=[1276, 74], edge_attr=[2676, 3], y=[64], batch=[1276], ptr=[65])
#
# Step 136:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2792], x=[1323, 74], edge_attr=[2792, 3], y=[64], batch=[1323], ptr=[65])
#
# Step 137:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2848], x=[1331, 74], edge_attr=[2848, 3], y=[64], batch=[1331], ptr=[65])
#
# Step 138:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2880], x=[1354, 74], edge_attr=[2880, 3], y=[64], batch=[1354], ptr=[65])
#
# Step 139:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2630], x=[1258, 74], edge_attr=[2630, 3], y=[64], batch=[1258], ptr=[65])
#
# Step 140:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3004], x=[1416, 74], edge_attr=[3004, 3], y=[64], batch=[1416], ptr=[65])
#
# Step 141:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2880], x=[1361, 74], edge_attr=[2880, 3], y=[64], batch=[1361], ptr=[65])
#
# Step 142:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3034], x=[1426, 74], edge_attr=[3034, 3], y=[64], batch=[1426], ptr=[65])
#
# Step 143:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2792], x=[1319, 74], edge_attr=[2792, 3], y=[64], batch=[1319], ptr=[65])
#
# Step 144:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3014], x=[1414, 74], edge_attr=[3014, 3], y=[64], batch=[1414], ptr=[65])
#
# Step 145:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3108], x=[1477, 74], edge_attr=[3108, 3], y=[64], batch=[1477], ptr=[65])
#
# Step 146:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2992], x=[1412, 74], edge_attr=[2992, 3], y=[64], batch=[1412], ptr=[65])
#
# Step 147:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2794], x=[1322, 74], edge_attr=[2794, 3], y=[64], batch=[1322], ptr=[65])
#
# Step 148:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3234], x=[1532, 74], edge_attr=[3234, 3], y=[64], batch=[1532], ptr=[65])
#
# Step 149:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2688], x=[1293, 74], edge_attr=[2688, 3], y=[64], batch=[1293], ptr=[65])
#
# Step 150:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2862], x=[1344, 74], edge_attr=[2862, 3], y=[64], batch=[1344], ptr=[65])
#
# Step 151:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3388], x=[1589, 74], edge_attr=[3388, 3], y=[64], batch=[1589], ptr=[65])
#
# Step 152:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2784], x=[1320, 74], edge_attr=[2784, 3], y=[64], batch=[1320], ptr=[65])
#
# Step 153:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3078], x=[1450, 74], edge_attr=[3078, 3], y=[64], batch=[1450], ptr=[65])
#
# Step 154:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2900], x=[1369, 74], edge_attr=[2900, 3], y=[64], batch=[1369], ptr=[65])
#
# Step 155:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2870], x=[1356, 74], edge_attr=[2870, 3], y=[64], batch=[1356], ptr=[65])
#
# Step 156:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2928], x=[1381, 74], edge_attr=[2928, 3], y=[64], batch=[1381], ptr=[65])
#
# Step 157:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3286], x=[1537, 74], edge_attr=[3286, 3], y=[64], batch=[1537], ptr=[65])
#
# Step 158:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2788], x=[1315, 74], edge_attr=[2788, 3], y=[64], batch=[1315], ptr=[65])
#
# Step 159:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3112], x=[1453, 74], edge_attr=[3112, 3], y=[64], batch=[1453], ptr=[65])
#
# Step 160:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2880], x=[1368, 74], edge_attr=[2880, 3], y=[64], batch=[1368], ptr=[65])
#
# Step 161:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2824], x=[1336, 74], edge_attr=[2824, 3], y=[64], batch=[1336], ptr=[65])
#
# Step 162:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2834], x=[1335, 74], edge_attr=[2834, 3], y=[64], batch=[1335], ptr=[65])
#
# Step 163:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2768], x=[1312, 74], edge_attr=[2768, 3], y=[64], batch=[1312], ptr=[65])
#
# Step 164:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2922], x=[1391, 74], edge_attr=[2922, 3], y=[64], batch=[1391], ptr=[65])
#
# Step 165:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2802], x=[1325, 74], edge_attr=[2802, 3], y=[64], batch=[1325], ptr=[65])
#
# Step 166:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3028], x=[1415, 74], edge_attr=[3028, 3], y=[64], batch=[1415], ptr=[65])
#
# Step 167:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2600], x=[1235, 74], edge_attr=[2600, 3], y=[64], batch=[1235], ptr=[65])
#
# Step 168:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3086], x=[1448, 74], edge_attr=[3086, 3], y=[64], batch=[1448], ptr=[65])
#
# Step 169:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2968], x=[1408, 74], edge_attr=[2968, 3], y=[64], batch=[1408], ptr=[65])
#
# Step 170:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2592], x=[1229, 74], edge_attr=[2592, 3], y=[64], batch=[1229], ptr=[65])
#
# Step 171:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2954], x=[1400, 74], edge_attr=[2954, 3], y=[64], batch=[1400], ptr=[65])
#
# Step 172:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2854], x=[1345, 74], edge_attr=[2854, 3], y=[64], batch=[1345], ptr=[65])
#
# Step 173:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2716], x=[1282, 74], edge_attr=[2716, 3], y=[64], batch=[1282], ptr=[65])
#
# Step 174:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2980], x=[1395, 74], edge_attr=[2980, 3], y=[64], batch=[1395], ptr=[65])
#
# Step 175:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3320], x=[1539, 74], edge_attr=[3320, 3], y=[64], batch=[1539], ptr=[65])
#
# Step 176:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2974], x=[1383, 74], edge_attr=[2974, 3], y=[64], batch=[1383], ptr=[65])
#
# Step 177:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2852], x=[1354, 74], edge_attr=[2852, 3], y=[64], batch=[1354], ptr=[65])
#
# Step 178:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2668], x=[1279, 74], edge_attr=[2668, 3], y=[64], batch=[1279], ptr=[65])
#
# Step 179:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2886], x=[1377, 74], edge_attr=[2886, 3], y=[64], batch=[1377], ptr=[65])
#
# Step 180:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2936], x=[1372, 74], edge_attr=[2936, 3], y=[64], batch=[1372], ptr=[65])
#
# Step 181:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2626], x=[1232, 74], edge_attr=[2626, 3], y=[64], batch=[1232], ptr=[65])
#
# Step 182:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3030], x=[1425, 74], edge_attr=[3030, 3], y=[64], batch=[1425], ptr=[65])
#
# Step 183:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3090], x=[1472, 74], edge_attr=[3090, 3], y=[64], batch=[1472], ptr=[65])
#
# Step 184:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2918], x=[1367, 74], edge_attr=[2918, 3], y=[64], batch=[1367], ptr=[65])
#
# Step 185:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3222], x=[1499, 74], edge_attr=[3222, 3], y=[64], batch=[1499], ptr=[65])
#
# Step 186:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2884], x=[1368, 74], edge_attr=[2884, 3], y=[64], batch=[1368], ptr=[65])
#
# Step 187:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2874], x=[1366, 74], edge_attr=[2874, 3], y=[64], batch=[1366], ptr=[65])
#
# Step 188:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2814], x=[1333, 74], edge_attr=[2814, 3], y=[64], batch=[1333], ptr=[65])
#
# Step 189:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3036], x=[1430, 74], edge_attr=[3036, 3], y=[64], batch=[1430], ptr=[65])
#
# Step 190:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2806], x=[1339, 74], edge_attr=[2806, 3], y=[64], batch=[1339], ptr=[65])
#
# Step 191:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2762], x=[1311, 74], edge_attr=[2762, 3], y=[64], batch=[1311], ptr=[65])
#
# Step 192:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2694], x=[1275, 74], edge_attr=[2694, 3], y=[64], batch=[1275], ptr=[65])
#
# Step 193:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2684], x=[1266, 74], edge_attr=[2684, 3], y=[64], batch=[1266], ptr=[65])
#
# Step 194:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2794], x=[1317, 74], edge_attr=[2794, 3], y=[64], batch=[1317], ptr=[65])
#
# Step 195:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2772], x=[1305, 74], edge_attr=[2772, 3], y=[64], batch=[1305], ptr=[65])
#
# Step 196:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2712], x=[1288, 74], edge_attr=[2712, 3], y=[64], batch=[1288], ptr=[65])
#
# Step 197:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3182], x=[1487, 74], edge_attr=[3182, 3], y=[64], batch=[1487], ptr=[65])
#
# Step 198:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3114], x=[1466, 74], edge_attr=[3114, 3], y=[64], batch=[1466], ptr=[65])
#
# Step 199:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2970], x=[1404, 74], edge_attr=[2970, 3], y=[64], batch=[1404], ptr=[65])
#
# Step 200:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2984], x=[1397, 74], edge_attr=[2984, 3], y=[64], batch=[1397], ptr=[65])
#
# Step 201:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2840], x=[1338, 74], edge_attr=[2840, 3], y=[64], batch=[1338], ptr=[65])
#
# Step 202:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2982], x=[1399, 74], edge_attr=[2982, 3], y=[64], batch=[1399], ptr=[65])
#
# Step 203:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2968], x=[1425, 74], edge_attr=[2968, 3], y=[64], batch=[1425], ptr=[65])
#
# Step 204:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3068], x=[1456, 74], edge_attr=[3068, 3], y=[64], batch=[1456], ptr=[65])
#
# Step 205:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3074], x=[1444, 74], edge_attr=[3074, 3], y=[64], batch=[1444], ptr=[65])
#
# Step 206:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3054], x=[1440, 74], edge_attr=[3054, 3], y=[64], batch=[1440], ptr=[65])
#
# Step 207:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2772], x=[1327, 74], edge_attr=[2772, 3], y=[64], batch=[1327], ptr=[65])
#
# Step 208:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2670], x=[1268, 74], edge_attr=[2670, 3], y=[64], batch=[1268], ptr=[65])
#
# Step 209:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2806], x=[1332, 74], edge_attr=[2806, 3], y=[64], batch=[1332], ptr=[65])
#
# Step 210:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2846], x=[1351, 74], edge_attr=[2846, 3], y=[64], batch=[1351], ptr=[65])
#
# Step 211:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2684], x=[1288, 74], edge_attr=[2684, 3], y=[64], batch=[1288], ptr=[65])
#
# Step 212:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2890], x=[1379, 74], edge_attr=[2890, 3], y=[64], batch=[1379], ptr=[65])
#
# Step 213:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2972], x=[1399, 74], edge_attr=[2972, 3], y=[64], batch=[1399], ptr=[65])
#
# Step 214:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2936], x=[1394, 74], edge_attr=[2936, 3], y=[64], batch=[1394], ptr=[65])
#
# Step 215:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2914], x=[1379, 74], edge_attr=[2914, 3], y=[64], batch=[1379], ptr=[65])
#
# Step 216:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3008], x=[1418, 74], edge_attr=[3008, 3], y=[64], batch=[1418], ptr=[65])
#
# Step 217:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2984], x=[1427, 74], edge_attr=[2984, 3], y=[64], batch=[1427], ptr=[65])
#
# Step 218:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3124], x=[1465, 74], edge_attr=[3124, 3], y=[64], batch=[1465], ptr=[65])
#
# Step 219:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2942], x=[1386, 74], edge_attr=[2942, 3], y=[64], batch=[1386], ptr=[65])
#
# Step 220:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3110], x=[1454, 74], edge_attr=[3110, 3], y=[64], batch=[1454], ptr=[65])
#
# Step 221:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2662], x=[1264, 74], edge_attr=[2662, 3], y=[64], batch=[1264], ptr=[65])
#
# Step 222:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2748], x=[1304, 74], edge_attr=[2748, 3], y=[64], batch=[1304], ptr=[65])
#
# Step 223:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3026], x=[1425, 74], edge_attr=[3026, 3], y=[64], batch=[1425], ptr=[65])
#
# Step 224:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3392], x=[1591, 74], edge_attr=[3392, 3], y=[64], batch=[1591], ptr=[65])
#
# Step 225:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2914], x=[1386, 74], edge_attr=[2914, 3], y=[64], batch=[1386], ptr=[65])
#
# Step 226:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3062], x=[1440, 74], edge_attr=[3062, 3], y=[64], batch=[1440], ptr=[65])
#
# Step 227:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2744], x=[1288, 74], edge_attr=[2744, 3], y=[64], batch=[1288], ptr=[65])
#
# Step 228:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2800], x=[1335, 74], edge_attr=[2800, 3], y=[64], batch=[1335], ptr=[65])
#
# Step 229:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2672], x=[1258, 74], edge_attr=[2672, 3], y=[64], batch=[1258], ptr=[65])
#
# Step 230:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2828], x=[1326, 74], edge_attr=[2828, 3], y=[64], batch=[1326], ptr=[65])
#
# Step 231:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3026], x=[1424, 74], edge_attr=[3026, 3], y=[64], batch=[1424], ptr=[65])
#
# Step 232:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2830], x=[1335, 74], edge_attr=[2830, 3], y=[64], batch=[1335], ptr=[65])
#
# Step 233:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2912], x=[1370, 74], edge_attr=[2912, 3], y=[64], batch=[1370], ptr=[65])
#
# Step 234:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3162], x=[1486, 74], edge_attr=[3162, 3], y=[64], batch=[1486], ptr=[65])
#
# Step 235:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2992], x=[1424, 74], edge_attr=[2992, 3], y=[64], batch=[1424], ptr=[65])
#
# Step 236:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2870], x=[1341, 74], edge_attr=[2870, 3], y=[64], batch=[1341], ptr=[65])
#
# Step 237:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2728], x=[1296, 74], edge_attr=[2728, 3], y=[64], batch=[1296], ptr=[65])
#
# Step 238:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3008], x=[1409, 74], edge_attr=[3008, 3], y=[64], batch=[1409], ptr=[65])
#
# Step 239:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2890], x=[1377, 74], edge_attr=[2890, 3], y=[64], batch=[1377], ptr=[65])
#
# Step 240:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2982], x=[1385, 74], edge_attr=[2982, 3], y=[64], batch=[1385], ptr=[65])
#
# Step 241:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2824], x=[1340, 74], edge_attr=[2824, 3], y=[64], batch=[1340], ptr=[65])
#
# Step 242:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2962], x=[1399, 74], edge_attr=[2962, 3], y=[64], batch=[1399], ptr=[65])
#
# Step 243:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2850], x=[1344, 74], edge_attr=[2850, 3], y=[64], batch=[1344], ptr=[65])
#
# Step 244:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2844], x=[1342, 74], edge_attr=[2844, 3], y=[64], batch=[1342], ptr=[65])
#
# Step 245:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2738], x=[1289, 74], edge_attr=[2738, 3], y=[64], batch=[1289], ptr=[65])
#
# Step 246:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2998], x=[1422, 74], edge_attr=[2998, 3], y=[64], batch=[1422], ptr=[65])
#
# Step 247:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2984], x=[1413, 74], edge_attr=[2984, 3], y=[64], batch=[1413], ptr=[65])
#
# Step 248:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2528], x=[1201, 74], edge_attr=[2528, 3], y=[64], batch=[1201], ptr=[65])
#
# Step 249:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2844], x=[1357, 74], edge_attr=[2844, 3], y=[64], batch=[1357], ptr=[65])
#
# Step 250:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3192], x=[1487, 74], edge_attr=[3192, 3], y=[64], batch=[1487], ptr=[65])
#
# Step 251:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2778], x=[1315, 74], edge_attr=[2778, 3], y=[64], batch=[1315], ptr=[65])
#
# Step 252:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2782], x=[1329, 74], edge_attr=[2782, 3], y=[64], batch=[1329], ptr=[65])
#
# Step 253:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2916], x=[1370, 74], edge_attr=[2916, 3], y=[64], batch=[1370], ptr=[65])
#
# Step 254:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2924], x=[1378, 74], edge_attr=[2924, 3], y=[64], batch=[1378], ptr=[65])
#
# Step 255:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2918], x=[1377, 74], edge_attr=[2918, 3], y=[64], batch=[1377], ptr=[65])
#
# Step 256:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2738], x=[1289, 74], edge_attr=[2738, 3], y=[64], batch=[1289], ptr=[65])
#
# Step 257:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2534], x=[1206, 74], edge_attr=[2534, 3], y=[64], batch=[1206], ptr=[65])
#
# Step 258:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2720], x=[1276, 74], edge_attr=[2720, 3], y=[64], batch=[1276], ptr=[65])
#
# Step 259:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2764], x=[1313, 74], edge_attr=[2764, 3], y=[64], batch=[1313], ptr=[65])
#
# Step 260:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2766], x=[1309, 74], edge_attr=[2766, 3], y=[64], batch=[1309], ptr=[65])
#
# Step 261:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3122], x=[1470, 74], edge_attr=[3122, 3], y=[64], batch=[1470], ptr=[65])
#
# Step 262:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2930], x=[1386, 74], edge_attr=[2930, 3], y=[64], batch=[1386], ptr=[65])
#
# Step 263:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2918], x=[1376, 74], edge_attr=[2918, 3], y=[64], batch=[1376], ptr=[65])
#
# Step 264:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2810], x=[1334, 74], edge_attr=[2810, 3], y=[64], batch=[1334], ptr=[65])
#
# Step 265:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2868], x=[1364, 74], edge_attr=[2868, 3], y=[64], batch=[1364], ptr=[65])
#
# Step 266:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3132], x=[1469, 74], edge_attr=[3132, 3], y=[64], batch=[1469], ptr=[65])
#
# Step 267:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2882], x=[1362, 74], edge_attr=[2882, 3], y=[64], batch=[1362], ptr=[65])
#
# Step 268:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2816], x=[1338, 74], edge_attr=[2816, 3], y=[64], batch=[1338], ptr=[65])
#
# Step 269:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3018], x=[1445, 74], edge_attr=[3018, 3], y=[64], batch=[1445], ptr=[65])
#
# Step 270:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2648], x=[1259, 74], edge_attr=[2648, 3], y=[64], batch=[1259], ptr=[65])
#
# Step 271:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2776], x=[1305, 74], edge_attr=[2776, 3], y=[64], batch=[1305], ptr=[65])
#
# Step 272:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3160], x=[1491, 74], edge_attr=[3160, 3], y=[64], batch=[1491], ptr=[65])
#
# Step 273:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2650], x=[1252, 74], edge_attr=[2650, 3], y=[64], batch=[1252], ptr=[65])
#
# Step 274:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3040], x=[1433, 74], edge_attr=[3040, 3], y=[64], batch=[1433], ptr=[65])
#
# Step 275:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3140], x=[1464, 74], edge_attr=[3140, 3], y=[64], batch=[1464], ptr=[65])
#
# Step 276:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3072], x=[1442, 74], edge_attr=[3072, 3], y=[64], batch=[1442], ptr=[65])
#
# Step 277:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2918], x=[1369, 74], edge_attr=[2918, 3], y=[64], batch=[1369], ptr=[65])
#
# Step 278:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2834], x=[1353, 74], edge_attr=[2834, 3], y=[64], batch=[1353], ptr=[65])
#
# Step 279:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3062], x=[1444, 74], edge_attr=[3062, 3], y=[64], batch=[1444], ptr=[65])
#
# Step 280:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2948], x=[1397, 74], edge_attr=[2948, 3], y=[64], batch=[1397], ptr=[65])
#
# Step 281:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2886], x=[1359, 74], edge_attr=[2886, 3], y=[64], batch=[1359], ptr=[65])
#
# Step 282:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3120], x=[1468, 74], edge_attr=[3120, 3], y=[64], batch=[1468], ptr=[65])
#
# Step 283:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2912], x=[1393, 74], edge_attr=[2912, 3], y=[64], batch=[1393], ptr=[65])
#
# Step 284:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2856], x=[1335, 74], edge_attr=[2856, 3], y=[64], batch=[1335], ptr=[65])
#
# Step 285:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2968], x=[1383, 74], edge_attr=[2968, 3], y=[64], batch=[1383], ptr=[65])
#
# Step 286:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3236], x=[1516, 74], edge_attr=[3236, 3], y=[64], batch=[1516], ptr=[65])
#
# Step 287:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2780], x=[1319, 74], edge_attr=[2780, 3], y=[64], batch=[1319], ptr=[65])
#
# Step 288:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2924], x=[1365, 74], edge_attr=[2924, 3], y=[64], batch=[1365], ptr=[65])
#
# Step 289:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2906], x=[1383, 74], edge_attr=[2906, 3], y=[64], batch=[1383], ptr=[65])
#
# Step 290:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3000], x=[1428, 74], edge_attr=[3000, 3], y=[64], batch=[1428], ptr=[65])
#
# Step 291:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2854], x=[1358, 74], edge_attr=[2854, 3], y=[64], batch=[1358], ptr=[65])
#
# Step 292:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2898], x=[1359, 74], edge_attr=[2898, 3], y=[64], batch=[1359], ptr=[65])
#
# Step 293:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2926], x=[1373, 74], edge_attr=[2926, 3], y=[64], batch=[1373], ptr=[65])
#
# Step 294:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2908], x=[1368, 74], edge_attr=[2908, 3], y=[64], batch=[1368], ptr=[65])
#
# Step 295:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3224], x=[1517, 74], edge_attr=[3224, 3], y=[64], batch=[1517], ptr=[65])
#
# Step 296:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2720], x=[1299, 74], edge_attr=[2720, 3], y=[64], batch=[1299], ptr=[65])
#
# Step 297:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3176], x=[1490, 74], edge_attr=[3176, 3], y=[64], batch=[1490], ptr=[65])
#
# Step 298:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2838], x=[1355, 74], edge_attr=[2838, 3], y=[64], batch=[1355], ptr=[65])
#
# Step 299:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2918], x=[1383, 74], edge_attr=[2918, 3], y=[64], batch=[1383], ptr=[65])
#
# Step 300:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2578], x=[1232, 74], edge_attr=[2578, 3], y=[64], batch=[1232], ptr=[65])
#
# Step 301:
# =======
# Number of graphs in the current batch: 64
# ...
# Step 901:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3246], x=[1516, 74], edge_attr=[3246, 3], y=[64], batch=[1516], ptr=[65])
#
# Step 902:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2952], x=[1395, 74], edge_attr=[2952, 3], y=[64], batch=[1395], ptr=[65])
#
# Step 903:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2914], x=[1367, 74], edge_attr=[2914, 3], y=[64], batch=[1367], ptr=[65])
#
# Step 904:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3106], x=[1467, 74], edge_attr=[3106, 3], y=[64], batch=[1467], ptr=[65])
#
# Step 905:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2790], x=[1319, 74], edge_attr=[2790, 3], y=[64], batch=[1319], ptr=[65])
#
# Step 906:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2700], x=[1294, 74], edge_attr=[2700, 3], y=[64], batch=[1294], ptr=[65])
#
# Step 907:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2990], x=[1395, 74], edge_attr=[2990, 3], y=[64], batch=[1395], ptr=[65])
#
# Step 908:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3162], x=[1500, 74], edge_attr=[3162, 3], y=[64], batch=[1500], ptr=[65])
#
# Step 909:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2796], x=[1315, 74], edge_attr=[2796, 3], y=[64], batch=[1315], ptr=[65])
#
# Step 910:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3004], x=[1406, 74], edge_attr=[3004, 3], y=[64], batch=[1406], ptr=[65])
#
# Step 911:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2984], x=[1418, 74], edge_attr=[2984, 3], y=[64], batch=[1418], ptr=[65])
#
# Step 912:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3118], x=[1482, 74], edge_attr=[3118, 3], y=[64], batch=[1482], ptr=[65])
#
# Step 913:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2710], x=[1287, 74], edge_attr=[2710, 3], y=[64], batch=[1287], ptr=[65])
#
# Step 914:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3158], x=[1495, 74], edge_attr=[3158, 3], y=[64], batch=[1495], ptr=[65])
#
# Step 915:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2904], x=[1387, 74], edge_attr=[2904, 3], y=[64], batch=[1387], ptr=[65])
#
# Step 916:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2928], x=[1381, 74], edge_attr=[2928, 3], y=[64], batch=[1381], ptr=[65])
#
# Step 917:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3010], x=[1408, 74], edge_attr=[3010, 3], y=[64], batch=[1408], ptr=[65])
#
# Step 918:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3166], x=[1501, 74], edge_attr=[3166, 3], y=[64], batch=[1501], ptr=[65])
#
# Step 919:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2860], x=[1352, 74], edge_attr=[2860, 3], y=[64], batch=[1352], ptr=[65])
#
# Step 920:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2822], x=[1330, 74], edge_attr=[2822, 3], y=[64], batch=[1330], ptr=[65])
#
# Step 921:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2886], x=[1349, 74], edge_attr=[2886, 3], y=[64], batch=[1349], ptr=[65])
#
# Step 922:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2904], x=[1349, 74], edge_attr=[2904, 3], y=[64], batch=[1349], ptr=[65])
#
# Step 923:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2942], x=[1386, 74], edge_attr=[2942, 3], y=[64], batch=[1386], ptr=[65])
#
# Step 924:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3300], x=[1537, 74], edge_attr=[3300, 3], y=[64], batch=[1537], ptr=[65])
#
# Step 925:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2920], x=[1371, 74], edge_attr=[2920, 3], y=[64], batch=[1371], ptr=[65])
#
# Step 926:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2958], x=[1405, 74], edge_attr=[2958, 3], y=[64], batch=[1405], ptr=[65])
#
# Step 927:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2760], x=[1303, 74], edge_attr=[2760, 3], y=[64], batch=[1303], ptr=[65])
#
# Step 928:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2716], x=[1280, 74], edge_attr=[2716, 3], y=[64], batch=[1280], ptr=[65])
#
# Step 929:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2634], x=[1253, 74], edge_attr=[2634, 3], y=[64], batch=[1253], ptr=[65])
#
# Step 930:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2690], x=[1276, 74], edge_attr=[2690, 3], y=[64], batch=[1276], ptr=[65])
#
# Step 931:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2742], x=[1286, 74], edge_attr=[2742, 3], y=[64], batch=[1286], ptr=[65])
#
# Step 932:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2928], x=[1387, 74], edge_attr=[2928, 3], y=[64], batch=[1387], ptr=[65])
#
# Step 933:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2726], x=[1284, 74], edge_attr=[2726, 3], y=[64], batch=[1284], ptr=[65])
#
# Step 934:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2920], x=[1370, 74], edge_attr=[2920, 3], y=[64], batch=[1370], ptr=[65])
#
# Step 935:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2862], x=[1344, 74], edge_attr=[2862, 3], y=[64], batch=[1344], ptr=[65])
#
# Step 936:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2974], x=[1404, 74], edge_attr=[2974, 3], y=[64], batch=[1404], ptr=[65])
#
# Step 937:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2742], x=[1291, 74], edge_attr=[2742, 3], y=[64], batch=[1291], ptr=[65])
#
# Step 938:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2918], x=[1373, 74], edge_attr=[2918, 3], y=[64], batch=[1373], ptr=[65])
#
# Step 939:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3034], x=[1423, 74], edge_attr=[3034, 3], y=[64], batch=[1423], ptr=[65])
#
# Step 940:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3020], x=[1409, 74], edge_attr=[3020, 3], y=[64], batch=[1409], ptr=[65])
#
# Step 941:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2818], x=[1334, 74], edge_attr=[2818, 3], y=[64], batch=[1334], ptr=[65])
#
# Step 942:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2816], x=[1336, 74], edge_attr=[2816, 3], y=[64], batch=[1336], ptr=[65])
#
# Step 943:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3018], x=[1419, 74], edge_attr=[3018, 3], y=[64], batch=[1419], ptr=[65])
#
# Step 944:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2904], x=[1374, 74], edge_attr=[2904, 3], y=[64], batch=[1374], ptr=[65])
#
# Step 945:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3126], x=[1472, 74], edge_attr=[3126, 3], y=[64], batch=[1472], ptr=[65])
#
# Step 946:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2802], x=[1313, 74], edge_attr=[2802, 3], y=[64], batch=[1313], ptr=[65])
#
# Step 947:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2854], x=[1353, 74], edge_attr=[2854, 3], y=[64], batch=[1353], ptr=[65])
#
# Step 948:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2894], x=[1365, 74], edge_attr=[2894, 3], y=[64], batch=[1365], ptr=[65])
#
# Step 949:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3222], x=[1527, 74], edge_attr=[3222, 3], y=[64], batch=[1527], ptr=[65])
#
# Step 950:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2754], x=[1319, 74], edge_attr=[2754, 3], y=[64], batch=[1319], ptr=[65])
#
# Step 951:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2620], x=[1241, 74], edge_attr=[2620, 3], y=[64], batch=[1241], ptr=[65])
#
# Step 952:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2896], x=[1364, 74], edge_attr=[2896, 3], y=[64], batch=[1364], ptr=[65])
#
# Step 953:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2914], x=[1388, 74], edge_attr=[2914, 3], y=[64], batch=[1388], ptr=[65])
#
# Step 954:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2820], x=[1330, 74], edge_attr=[2820, 3], y=[64], batch=[1330], ptr=[65])
#
# Step 955:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3004], x=[1420, 74], edge_attr=[3004, 3], y=[64], batch=[1420], ptr=[65])
#
# Step 956:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2780], x=[1322, 74], edge_attr=[2780, 3], y=[64], batch=[1322], ptr=[65])
#
# Step 957:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2734], x=[1288, 74], edge_attr=[2734, 3], y=[64], batch=[1288], ptr=[65])
#
# Step 958:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3124], x=[1470, 74], edge_attr=[3124, 3], y=[64], batch=[1470], ptr=[65])
#
# Step 959:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2886], x=[1373, 74], edge_attr=[2886, 3], y=[64], batch=[1373], ptr=[65])
#
# Step 960:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2868], x=[1351, 74], edge_attr=[2868, 3], y=[64], batch=[1351], ptr=[65])
#
# Step 961:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2894], x=[1366, 74], edge_attr=[2894, 3], y=[64], batch=[1366], ptr=[65])
#
# Step 962:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2894], x=[1352, 74], edge_attr=[2894, 3], y=[64], batch=[1352], ptr=[65])
#
# Step 963:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2874], x=[1376, 74], edge_attr=[2874, 3], y=[64], batch=[1376], ptr=[65])
#
# Step 964:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2846], x=[1335, 74], edge_attr=[2846, 3], y=[64], batch=[1335], ptr=[65])
#
# Step 965:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3118], x=[1491, 74], edge_attr=[3118, 3], y=[64], batch=[1491], ptr=[65])
#
# Step 966:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2826], x=[1319, 74], edge_attr=[2826, 3], y=[64], batch=[1319], ptr=[65])
#
# Step 967:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3046], x=[1432, 74], edge_attr=[3046, 3], y=[64], batch=[1432], ptr=[65])
#
# Step 968:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2868], x=[1359, 74], edge_attr=[2868, 3], y=[64], batch=[1359], ptr=[65])
#
# Step 969:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3162], x=[1482, 74], edge_attr=[3162, 3], y=[64], batch=[1482], ptr=[65])
#
# Step 970:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2706], x=[1269, 74], edge_attr=[2706, 3], y=[64], batch=[1269], ptr=[65])
#
# Step 971:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2744], x=[1303, 74], edge_attr=[2744, 3], y=[64], batch=[1303], ptr=[65])
#
# Step 972:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2980], x=[1408, 74], edge_attr=[2980, 3], y=[64], batch=[1408], ptr=[65])
#
# Step 973:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2922], x=[1367, 74], edge_attr=[2922, 3], y=[64], batch=[1367], ptr=[65])
#
# Step 974:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2950], x=[1388, 74], edge_attr=[2950, 3], y=[64], batch=[1388], ptr=[65])
#
# Step 975:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2956], x=[1389, 74], edge_attr=[2956, 3], y=[64], batch=[1389], ptr=[65])
#
# Step 976:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3060], x=[1440, 74], edge_attr=[3060, 3], y=[64], batch=[1440], ptr=[65])
#
# Step 977:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2972], x=[1411, 74], edge_attr=[2972, 3], y=[64], batch=[1411], ptr=[65])
#
# Step 978:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2994], x=[1410, 74], edge_attr=[2994, 3], y=[64], batch=[1410], ptr=[65])
#
# Step 979:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3142], x=[1466, 74], edge_attr=[3142, 3], y=[64], batch=[1466], ptr=[65])
#
# Step 980:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2872], x=[1350, 74], edge_attr=[2872, 3], y=[64], batch=[1350], ptr=[65])
#
# Step 981:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2972], x=[1404, 74], edge_attr=[2972, 3], y=[64], batch=[1404], ptr=[65])
#
# Step 982:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2806], x=[1329, 74], edge_attr=[2806, 3], y=[64], batch=[1329], ptr=[65])
#
# Step 983:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2960], x=[1380, 74], edge_attr=[2960, 3], y=[64], batch=[1380], ptr=[65])
#
# Step 984:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3238], x=[1527, 74], edge_attr=[3238, 3], y=[64], batch=[1527], ptr=[65])
#
# Step 985:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2896], x=[1365, 74], edge_attr=[2896, 3], y=[64], batch=[1365], ptr=[65])
#
# Step 986:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3070], x=[1449, 74], edge_attr=[3070, 3], y=[64], batch=[1449], ptr=[65])
#
# Step 987:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3042], x=[1448, 74], edge_attr=[3042, 3], y=[64], batch=[1448], ptr=[65])
#
# Step 988:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2830], x=[1334, 74], edge_attr=[2830, 3], y=[64], batch=[1334], ptr=[65])
#
# Step 989:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3028], x=[1417, 74], edge_attr=[3028, 3], y=[64], batch=[1417], ptr=[65])
#
# Step 990:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3092], x=[1459, 74], edge_attr=[3092, 3], y=[64], batch=[1459], ptr=[65])
#
# Step 991:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2760], x=[1307, 74], edge_attr=[2760, 3], y=[64], batch=[1307], ptr=[65])
#
# Step 992:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2998], x=[1409, 74], edge_attr=[2998, 3], y=[64], batch=[1409], ptr=[65])
#
# Step 993:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2720], x=[1284, 74], edge_attr=[2720, 3], y=[64], batch=[1284], ptr=[65])
#
# Step 994:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3074], x=[1439, 74], edge_attr=[3074, 3], y=[64], batch=[1439], ptr=[65])
#
# Step 995:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2778], x=[1321, 74], edge_attr=[2778, 3], y=[64], batch=[1321], ptr=[65])
#
# Step 996:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3280], x=[1552, 74], edge_attr=[3280, 3], y=[64], batch=[1552], ptr=[65])
#
# Step 997:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2888], x=[1359, 74], edge_attr=[2888, 3], y=[64], batch=[1359], ptr=[65])
#
# Step 998:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3080], x=[1451, 74], edge_attr=[3080, 3], y=[64], batch=[1451], ptr=[65])
#
# Step 999:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 3078], x=[1447, 74], edge_attr=[3078, 3], y=[64], batch=[1447], ptr=[65])
#
# Step 1000:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2798], x=[1321, 74], edge_attr=[2798, 3], y=[64], batch=[1321], ptr=[65])

# %% [markdown]
# Here, we opt for a `batch_size` of 64, leading to 3 (randomly shuffled) mini-batches, containing all $2 \cdot 64+22 = 150$ graphs.
#
# Furthermore, each `Batch` object is equipped with a **`batch` vector**, which maps each node to its respective graph in the batch:
#
# $$
# \textrm{batch} = [ 0, \ldots, 0, 1, \ldots, 1, 2, \ldots ]
# $$

# %% [markdown]
# ## Training a Graph Neural Network (GNN)
#
# Training a GNN for graph classification usually follows a simple recipe:
#
# 1. Embed each node by performing multiple rounds of message passing
# 2. Aggregate node embeddings into a unified graph embedding (**readout layer**)
# 3. Train a final classifier on the graph embedding
#
# There exists multiple **readout layers** in literature, but the most common one is to simply take the average of node embeddings:
#
# $$
# \mathbf{x}_{\mathcal{G}} = \frac{1}{|\mathcal{V}|} \sum_{v \in \mathcal{V}} \mathcal{x}^{(L)}_v
# $$
#
# PyTorch Geometric provides this functionality via [`torch_geometric.nn.global_mean_pool`](https://pytorch-geometric.readthedocs.io/en/latest/modules/nn.html#torch_geometric.nn.glob.global_mean_pool), which takes in the node embeddings of all nodes in the mini-batch and the assignment vector `batch` to compute a graph embedding of size `[batch_size, hidden_channels]` for each graph in the batch.
#
# The final architecture for applying GNNs to the task of graph classification then looks as follows and allows for complete end-to-end training:

# %%
from torch.nn import Linear
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.nn import global_mean_pool


class GCN(torch.nn.Module):
    def __init__(self, hidden_channels):
        super(GCN, self).__init__()
        torch.manual_seed(12345)
        self.conv1 = GCNConv(dataset.num_node_features, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels)
        self.conv3 = GCNConv(hidden_channels, hidden_channels)
        self.lin = Linear(hidden_channels, dataset.num_classes)

    def forward(self, x, edge_index, batch):
        # 1. Obtain node embeddings 
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = self.conv2(x, edge_index)
        x = x.relu()
        x = self.conv3(x, edge_index)

        # 2. Readout layer
        x = global_mean_pool(x, batch)  # [batch_size, hidden_channels]

        # 3. Apply a final classifier
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin(x)
        
        return x

model = GCN(hidden_channels=64)
print(model)
# Out:
# GCN(
#   (conv1): GCNConv(74, 64)
#   (conv2): GCNConv(64, 64)
#   (conv3): GCNConv(64, 64)
#   (lin): Linear(in_features=64, out_features=2, bias=True)
# )

# %% [markdown]
# Here, we again make use of the [`GCNConv`](https://pytorch-geometric.readthedocs.io/en/latest/modules/nn.html#torch_geometric.nn.conv.GCNConv) with $\mathrm{ReLU}(x) = \max(x, 0)$ activation for obtaining localized node embeddings, before we apply our final classifier on top of a graph readout layer.
#
# Let's train our network for a few epochs to see how well it performs on the training as well as test set:

# %%
from IPython.display import Javascript
display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 300})'''))

model = GCN(hidden_channels=64)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
criterion = torch.nn.CrossEntropyLoss()

def train():
    model.train()

    for data in train_loader:  # Iterate in batches over the training dataset.
         out = model(data.x, data.edge_index, data.batch)  # Perform a single forward pass.
         loss = criterion(out, data.y)  # Compute the loss.
         loss.backward()  # Derive gradients.
         optimizer.step()  # Update parameters based on gradients.
         optimizer.zero_grad()  # Clear gradients.
         trainloss = torch.mean(loss)
         return trainloss

def test(loader):
     model.eval()

     correct = 0
     for data in loader:  # Iterate in batches over the training/test dataset.
         out = model(data.x, data.edge_index, data.batch)  
         pred = out.argmax(dim=1)  # Use the class with highest probability.
         correct += int((pred == data.y).sum())  # Check against ground-truth labels.
     return correct / len(loader.dataset)  # Derive ratio of correct predictions.

train_losses = []
train_accuracy = []
test_accuracy = []

epoch = 2000
for i in range(1, epoch+1):
    trainloss = train()
    train_acc = test(train_loader)
    test_acc = test(test_loader)

    train_losses.append(trainloss.detach().numpy().tolist())
    train_accuracy.append(train_acc)
    test_accuracy.append(test_acc)
    
    #print(f'Trainloss: {trainloss:.4f}')
    print(f'Epoch: {i:03d}, Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}')
# Out:
# Epoch: 001, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 002, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 003, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 004, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 005, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 006, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 007, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 008, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 009, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 010, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 011, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 012, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 013, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 014, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 015, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 016, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 017, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 018, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 019, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 020, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 021, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 022, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 023, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 024, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 025, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 026, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 027, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 028, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 029, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 030, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 031, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 032, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 033, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 034, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 035, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 036, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 037, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 038, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 039, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 040, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 041, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 042, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 043, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 044, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 045, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 046, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 047, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 048, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 049, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 050, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 051, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 052, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 053, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 054, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 055, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 056, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 057, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 058, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 059, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 060, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 061, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 062, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 063, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 064, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 065, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 066, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 067, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 068, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 069, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 070, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 071, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 072, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 073, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 074, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 075, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 076, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 077, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 078, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 079, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 080, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 081, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 082, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 083, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 084, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 085, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 086, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 087, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 088, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 089, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 090, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 091, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 092, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 093, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 094, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 095, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 096, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 097, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 098, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 099, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 100, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 101, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 102, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 103, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 104, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 105, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 106, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 107, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 108, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 109, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 110, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 111, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 112, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 113, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 114, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 115, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 116, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 117, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 118, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 119, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 120, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 121, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 122, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 123, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 124, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 125, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 126, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 127, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 128, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 129, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 130, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 131, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 132, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 133, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 134, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 135, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 136, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 137, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 138, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 139, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 140, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 141, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 142, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 143, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 144, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 145, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 146, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 147, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 148, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 149, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 150, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 151, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 152, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 153, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 154, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 155, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 156, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 157, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 158, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 159, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 160, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 161, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 162, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 163, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 164, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 165, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 166, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 167, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 168, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 169, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 170, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 171, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 172, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 173, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 174, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 175, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 176, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 177, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 178, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 179, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 180, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 181, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 182, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 183, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 184, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 185, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 186, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 187, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 188, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 189, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 190, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 191, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 192, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 193, Train Acc: 0.8796, Test Acc: 0.8808
# Epoch: 194, Train Acc: 0.8796, Test Acc: 0.8808
# Epoch: 195, Train Acc: 0.8796, Test Acc: 0.8808
# Epoch: 196, Train Acc: 0.8796, Test Acc: 0.8808
# Epoch: 197, Train Acc: 0.8796, Test Acc: 0.8808
# Epoch: 198, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 199, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 200, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 201, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 202, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 203, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 204, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 205, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 206, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 207, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 208, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 209, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 210, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 211, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 212, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 213, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 214, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 215, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 216, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 217, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 218, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 219, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 220, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 221, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 222, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 223, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 224, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 225, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 226, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 227, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 228, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 229, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 230, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 231, Train Acc: 0.8796, Test Acc: 0.8808
# Epoch: 232, Train Acc: 0.8796, Test Acc: 0.8808
# Epoch: 233, Train Acc: 0.8796, Test Acc: 0.8808
# Epoch: 234, Train Acc: 0.8795, Test Acc: 0.8807
# Epoch: 235, Train Acc: 0.8794, Test Acc: 0.8806
# Epoch: 236, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 237, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 238, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 239, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 240, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 241, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 242, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 243, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 244, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 245, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 246, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 247, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 248, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 249, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 250, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 251, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 252, Train Acc: 0.8794, Test Acc: 0.8806
# Epoch: 253, Train Acc: 0.8794, Test Acc: 0.8806
# Epoch: 254, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 255, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 256, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 257, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 258, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 259, Train Acc: 0.8795, Test Acc: 0.8807
# Epoch: 260, Train Acc: 0.8795, Test Acc: 0.8807
# Epoch: 261, Train Acc: 0.8795, Test Acc: 0.8807
# Epoch: 262, Train Acc: 0.8795, Test Acc: 0.8807
# Epoch: 263, Train Acc: 0.8795, Test Acc: 0.8807
# Epoch: 264, Train Acc: 0.8795, Test Acc: 0.8807
# Epoch: 265, Train Acc: 0.8795, Test Acc: 0.8807
# Epoch: 266, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 267, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 268, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 269, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 270, Train Acc: 0.8794, Test Acc: 0.8806
# Epoch: 271, Train Acc: 0.8794, Test Acc: 0.8806
# Epoch: 272, Train Acc: 0.8794, Test Acc: 0.8806
# Epoch: 273, Train Acc: 0.8794, Test Acc: 0.8806
# Epoch: 274, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 275, Train Acc: 0.8794, Test Acc: 0.8806
# Epoch: 276, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 277, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 278, Train Acc: 0.8794, Test Acc: 0.8806
# Epoch: 279, Train Acc: 0.8794, Test Acc: 0.8806
# Epoch: 280, Train Acc: 0.8794, Test Acc: 0.8806
# Epoch: 281, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 282, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 283, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 284, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 285, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 286, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 287, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 288, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 289, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 290, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 291, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 292, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 293, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 294, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 295, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 296, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 297, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 298, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 299, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 300, Train Acc: 0.8795, Test Acc: 0.8807
# Epoch: 301, Train Acc: 0.8795, Test Acc: 0.8807
# Epoch: 302, Train Acc: 0.8795, Test Acc: 0.8807
# Epoch: 303, Train Acc: 0.8795, Test Acc: 0.8807
# Epoch: 304, Train Acc: 0.8795, Test Acc: 0.8807
# Epoch: 305, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 306, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 307, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 308, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 309, Train Acc: 0.8794, Test Acc: 0.8806
# Epoch: 310, Train Acc: 0.8794, Test Acc: 0.8806
# Epoch: 311, Train Acc: 0.8794, Test Acc: 0.8806
# Epoch: 312, Train Acc: 0.8793, Test Acc: 0.8805
# Epoch: 313, Train Acc: 0.8792, Test Acc: 0.8804
# Epoch: 314, Train Acc: 0.8790, Test Acc: 0.8799
# Epoch: 315, Train Acc: 0.8786, Test Acc: 0.8793
# Epoch: 316, Train Acc: 0.8782, Test Acc: 0.8790
# Epoch: 317, Train Acc: 0.8784, Test Acc: 0.8790
# Epoch: 318, Train Acc: 0.8784, Test Acc: 0.8792
# Epoch: 319, Train Acc: 0.8786, Test Acc: 0.8792
# Epoch: 320, Train Acc: 0.8787, Test Acc: 0.8792
# Epoch: 321, Train Acc: 0.8788, Test Acc: 0.8794
# Epoch: 322, Train Acc: 0.8789, Test Acc: 0.8797
# Epoch: 323, Train Acc: 0.8791, Test Acc: 0.8799
# Epoch: 324, Train Acc: 0.8792, Test Acc: 0.8803
# Epoch: 325, Train Acc: 0.8793, Test Acc: 0.8803
# Epoch: 326, Train Acc: 0.8793, Test Acc: 0.8805
# Epoch: 327, Train Acc: 0.8793, Test Acc: 0.8805
# Epoch: 328, Train Acc: 0.8793, Test Acc: 0.8805
# Epoch: 329, Train Acc: 0.8794, Test Acc: 0.8805
# Epoch: 330, Train Acc: 0.8794, Test Acc: 0.8805
# Epoch: 331, Train Acc: 0.8793, Test Acc: 0.8805
# Epoch: 332, Train Acc: 0.8794, Test Acc: 0.8805
# Epoch: 333, Train Acc: 0.8793, Test Acc: 0.8804
# Epoch: 334, Train Acc: 0.8793, Test Acc: 0.8804
# Epoch: 335, Train Acc: 0.8793, Test Acc: 0.8804
# Epoch: 336, Train Acc: 0.8794, Test Acc: 0.8803
# Epoch: 337, Train Acc: 0.8794, Test Acc: 0.8804
# Epoch: 338, Train Acc: 0.8794, Test Acc: 0.8804
# Epoch: 339, Train Acc: 0.8794, Test Acc: 0.8805
# Epoch: 340, Train Acc: 0.8794, Test Acc: 0.8805
# Epoch: 341, Train Acc: 0.8794, Test Acc: 0.8805
# Epoch: 342, Train Acc: 0.8794, Test Acc: 0.8805
# Epoch: 343, Train Acc: 0.8794, Test Acc: 0.8805
# Epoch: 344, Train Acc: 0.8795, Test Acc: 0.8805
# Epoch: 345, Train Acc: 0.8795, Test Acc: 0.8805
# Epoch: 346, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 347, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 348, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 349, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 350, Train Acc: 0.8795, Test Acc: 0.8807
# Epoch: 351, Train Acc: 0.8795, Test Acc: 0.8807
# Epoch: 352, Train Acc: 0.8796, Test Acc: 0.8808
# Epoch: 353, Train Acc: 0.8796, Test Acc: 0.8808
# Epoch: 354, Train Acc: 0.8796, Test Acc: 0.8808
# Epoch: 355, Train Acc: 0.8796, Test Acc: 0.8808
# Epoch: 356, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 357, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 358, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 359, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 360, Train Acc: 0.8796, Test Acc: 0.8808
# Epoch: 361, Train Acc: 0.8796, Test Acc: 0.8808
# Epoch: 362, Train Acc: 0.8796, Test Acc: 0.8808
# Epoch: 363, Train Acc: 0.8796, Test Acc: 0.8808
# Epoch: 364, Train Acc: 0.8796, Test Acc: 0.8808
# Epoch: 365, Train Acc: 0.8796, Test Acc: 0.8808
# Epoch: 366, Train Acc: 0.8796, Test Acc: 0.8808
# Epoch: 367, Train Acc: 0.8796, Test Acc: 0.8808
# Epoch: 368, Train Acc: 0.8796, Test Acc: 0.8808
# Epoch: 369, Train Acc: 0.8796, Test Acc: 0.8808
# Epoch: 370, Train Acc: 0.8796, Test Acc: 0.8808
# Epoch: 371, Train Acc: 0.8796, Test Acc: 0.8808
# Epoch: 372, Train Acc: 0.8796, Test Acc: 0.8808
# Epoch: 373, Train Acc: 0.8796, Test Acc: 0.8808
# Epoch: 374, Train Acc: 0.8796, Test Acc: 0.8808
# Epoch: 375, Train Acc: 0.8796, Test Acc: 0.8808
# Epoch: 376, Train Acc: 0.8796, Test Acc: 0.8808
# Epoch: 377, Train Acc: 0.8797, Test Acc: 0.8808
# Epoch: 378, Train Acc: 0.8797, Test Acc: 0.8807
# Epoch: 379, Train Acc: 0.8797, Test Acc: 0.8807
# Epoch: 380, Train Acc: 0.8797, Test Acc: 0.8808
# Epoch: 381, Train Acc: 0.8797, Test Acc: 0.8807
# Epoch: 382, Train Acc: 0.8797, Test Acc: 0.8808
# Epoch: 383, Train Acc: 0.8795, Test Acc: 0.8809
# Epoch: 384, Train Acc: 0.8795, Test Acc: 0.8809
# Epoch: 385, Train Acc: 0.8796, Test Acc: 0.8810
# Epoch: 386, Train Acc: 0.8795, Test Acc: 0.8810
# Epoch: 387, Train Acc: 0.8796, Test Acc: 0.8809
# Epoch: 388, Train Acc: 0.8796, Test Acc: 0.8809
# Epoch: 389, Train Acc: 0.8797, Test Acc: 0.8809
# Epoch: 390, Train Acc: 0.8796, Test Acc: 0.8808
# Epoch: 391, Train Acc: 0.8796, Test Acc: 0.8810
# Epoch: 392, Train Acc: 0.8797, Test Acc: 0.8808
# Epoch: 393, Train Acc: 0.8796, Test Acc: 0.8805
# Epoch: 394, Train Acc: 0.8795, Test Acc: 0.8803
# Epoch: 395, Train Acc: 0.8790, Test Acc: 0.8798
# Epoch: 396, Train Acc: 0.8794, Test Acc: 0.8804
# Epoch: 397, Train Acc: 0.8795, Test Acc: 0.8805
# Epoch: 398, Train Acc: 0.8796, Test Acc: 0.8805
# Epoch: 399, Train Acc: 0.8796, Test Acc: 0.8806
# Epoch: 400, Train Acc: 0.8795, Test Acc: 0.8807
# Epoch: 401, Train Acc: 0.8796, Test Acc: 0.8809
# Epoch: 402, Train Acc: 0.8796, Test Acc: 0.8808
# Epoch: 403, Train Acc: 0.8797, Test Acc: 0.8808
# Epoch: 404, Train Acc: 0.8798, Test Acc: 0.8809
# Epoch: 405, Train Acc: 0.8798, Test Acc: 0.8809
# Epoch: 406, Train Acc: 0.8798, Test Acc: 0.8809
# Epoch: 407, Train Acc: 0.8798, Test Acc: 0.8809
# Epoch: 408, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 409, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 410, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 411, Train Acc: 0.8799, Test Acc: 0.8809
# Epoch: 412, Train Acc: 0.8799, Test Acc: 0.8809
# Epoch: 413, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 414, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 415, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 416, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 417, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 418, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 419, Train Acc: 0.8800, Test Acc: 0.8810
# Epoch: 420, Train Acc: 0.8800, Test Acc: 0.8810
# Epoch: 421, Train Acc: 0.8800, Test Acc: 0.8810
# Epoch: 422, Train Acc: 0.8800, Test Acc: 0.8810
# Epoch: 423, Train Acc: 0.8800, Test Acc: 0.8810
# Epoch: 424, Train Acc: 0.8800, Test Acc: 0.8810
# Epoch: 425, Train Acc: 0.8800, Test Acc: 0.8810
# Epoch: 426, Train Acc: 0.8800, Test Acc: 0.8810
# Epoch: 427, Train Acc: 0.8800, Test Acc: 0.8810
# Epoch: 428, Train Acc: 0.8800, Test Acc: 0.8810
# Epoch: 429, Train Acc: 0.8801, Test Acc: 0.8814
# Epoch: 430, Train Acc: 0.8801, Test Acc: 0.8814
# Epoch: 431, Train Acc: 0.8801, Test Acc: 0.8813
# Epoch: 432, Train Acc: 0.8801, Test Acc: 0.8812
# Epoch: 433, Train Acc: 0.8801, Test Acc: 0.8812
# Epoch: 434, Train Acc: 0.8802, Test Acc: 0.8812
# Epoch: 435, Train Acc: 0.8802, Test Acc: 0.8814
# Epoch: 436, Train Acc: 0.8802, Test Acc: 0.8814
# Epoch: 437, Train Acc: 0.8802, Test Acc: 0.8814
# Epoch: 438, Train Acc: 0.8802, Test Acc: 0.8815
# Epoch: 439, Train Acc: 0.8802, Test Acc: 0.8817
# Epoch: 440, Train Acc: 0.8802, Test Acc: 0.8815
# Epoch: 441, Train Acc: 0.8801, Test Acc: 0.8815
# Epoch: 442, Train Acc: 0.8801, Test Acc: 0.8816
# Epoch: 443, Train Acc: 0.8801, Test Acc: 0.8815
# Epoch: 444, Train Acc: 0.8800, Test Acc: 0.8813
# Epoch: 445, Train Acc: 0.8800, Test Acc: 0.8813
# Epoch: 446, Train Acc: 0.8800, Test Acc: 0.8813
# Epoch: 447, Train Acc: 0.8800, Test Acc: 0.8813
# Epoch: 448, Train Acc: 0.8800, Test Acc: 0.8812
# Epoch: 449, Train Acc: 0.8799, Test Acc: 0.8813
# Epoch: 450, Train Acc: 0.8799, Test Acc: 0.8814
# Epoch: 451, Train Acc: 0.8800, Test Acc: 0.8812
# Epoch: 452, Train Acc: 0.8799, Test Acc: 0.8812
# Epoch: 453, Train Acc: 0.8799, Test Acc: 0.8812
# Epoch: 454, Train Acc: 0.8799, Test Acc: 0.8812
# Epoch: 455, Train Acc: 0.8799, Test Acc: 0.8812
# Epoch: 456, Train Acc: 0.8798, Test Acc: 0.8812
# Epoch: 457, Train Acc: 0.8798, Test Acc: 0.8812
# Epoch: 458, Train Acc: 0.8799, Test Acc: 0.8812
# Epoch: 459, Train Acc: 0.8799, Test Acc: 0.8811
# Epoch: 460, Train Acc: 0.8798, Test Acc: 0.8812
# Epoch: 461, Train Acc: 0.8800, Test Acc: 0.8812
# Epoch: 462, Train Acc: 0.8798, Test Acc: 0.8812
# Epoch: 463, Train Acc: 0.8799, Test Acc: 0.8812
# Epoch: 464, Train Acc: 0.8799, Test Acc: 0.8813
# Epoch: 465, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 466, Train Acc: 0.8798, Test Acc: 0.8812
# Epoch: 467, Train Acc: 0.8798, Test Acc: 0.8812
# Epoch: 468, Train Acc: 0.8799, Test Acc: 0.8812
# Epoch: 469, Train Acc: 0.8800, Test Acc: 0.8811
# Epoch: 470, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 471, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 472, Train Acc: 0.8798, Test Acc: 0.8810
# Epoch: 473, Train Acc: 0.8798, Test Acc: 0.8811
# Epoch: 474, Train Acc: 0.8798, Test Acc: 0.8812
# Epoch: 475, Train Acc: 0.8798, Test Acc: 0.8811
# Epoch: 476, Train Acc: 0.8798, Test Acc: 0.8810
# Epoch: 477, Train Acc: 0.8797, Test Acc: 0.8810
# Epoch: 478, Train Acc: 0.8798, Test Acc: 0.8809
# Epoch: 479, Train Acc: 0.8798, Test Acc: 0.8809
# Epoch: 480, Train Acc: 0.8798, Test Acc: 0.8810
# Epoch: 481, Train Acc: 0.8797, Test Acc: 0.8810
# Epoch: 482, Train Acc: 0.8797, Test Acc: 0.8810
# Epoch: 483, Train Acc: 0.8798, Test Acc: 0.8809
# Epoch: 484, Train Acc: 0.8798, Test Acc: 0.8808
# Epoch: 485, Train Acc: 0.8798, Test Acc: 0.8808
# Epoch: 486, Train Acc: 0.8798, Test Acc: 0.8809
# Epoch: 487, Train Acc: 0.8798, Test Acc: 0.8809
# Epoch: 488, Train Acc: 0.8798, Test Acc: 0.8810
# Epoch: 489, Train Acc: 0.8798, Test Acc: 0.8810
# Epoch: 490, Train Acc: 0.8798, Test Acc: 0.8811
# Epoch: 491, Train Acc: 0.8798, Test Acc: 0.8812
# Epoch: 492, Train Acc: 0.8798, Test Acc: 0.8810
# Epoch: 493, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 494, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 495, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 496, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 497, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 498, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 499, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 500, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 501, Train Acc: 0.8800, Test Acc: 0.8810
# Epoch: 502, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 503, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 504, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 505, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 506, Train Acc: 0.8798, Test Acc: 0.8810
# Epoch: 507, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 508, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 509, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 510, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 511, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 512, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 513, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 514, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 515, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 516, Train Acc: 0.8798, Test Acc: 0.8810
# Epoch: 517, Train Acc: 0.8798, Test Acc: 0.8811
# Epoch: 518, Train Acc: 0.8798, Test Acc: 0.8811
# Epoch: 519, Train Acc: 0.8799, Test Acc: 0.8811
# Epoch: 520, Train Acc: 0.8800, Test Acc: 0.8811
# Epoch: 521, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 522, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 523, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 524, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 525, Train Acc: 0.8798, Test Acc: 0.8810
# Epoch: 526, Train Acc: 0.8798, Test Acc: 0.8810
# Epoch: 527, Train Acc: 0.8798, Test Acc: 0.8810
# Epoch: 528, Train Acc: 0.8798, Test Acc: 0.8811
# Epoch: 529, Train Acc: 0.8798, Test Acc: 0.8810
# Epoch: 530, Train Acc: 0.8798, Test Acc: 0.8810
# Epoch: 531, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 532, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 533, Train Acc: 0.8799, Test Acc: 0.8811
# Epoch: 534, Train Acc: 0.8800, Test Acc: 0.8810
# Epoch: 535, Train Acc: 0.8800, Test Acc: 0.8811
# Epoch: 536, Train Acc: 0.8799, Test Acc: 0.8811
# Epoch: 537, Train Acc: 0.8799, Test Acc: 0.8811
# Epoch: 538, Train Acc: 0.8799, Test Acc: 0.8812
# Epoch: 539, Train Acc: 0.8798, Test Acc: 0.8812
# Epoch: 540, Train Acc: 0.8798, Test Acc: 0.8812
# Epoch: 541, Train Acc: 0.8798, Test Acc: 0.8811
# Epoch: 542, Train Acc: 0.8798, Test Acc: 0.8809
# Epoch: 543, Train Acc: 0.8798, Test Acc: 0.8812
# Epoch: 544, Train Acc: 0.8798, Test Acc: 0.8811
# Epoch: 545, Train Acc: 0.8797, Test Acc: 0.8812
# Epoch: 546, Train Acc: 0.8798, Test Acc: 0.8811
# Epoch: 547, Train Acc: 0.8796, Test Acc: 0.8808
# Epoch: 548, Train Acc: 0.8796, Test Acc: 0.8808
# Epoch: 549, Train Acc: 0.8796, Test Acc: 0.8809
# Epoch: 550, Train Acc: 0.8796, Test Acc: 0.8810
# Epoch: 551, Train Acc: 0.8797, Test Acc: 0.8808
# Epoch: 552, Train Acc: 0.8797, Test Acc: 0.8808
# Epoch: 553, Train Acc: 0.8797, Test Acc: 0.8808
# Epoch: 554, Train Acc: 0.8797, Test Acc: 0.8808
# Epoch: 555, Train Acc: 0.8797, Test Acc: 0.8808
# Epoch: 556, Train Acc: 0.8797, Test Acc: 0.8808
# Epoch: 557, Train Acc: 0.8796, Test Acc: 0.8808
# Epoch: 558, Train Acc: 0.8796, Test Acc: 0.8810
# Epoch: 559, Train Acc: 0.8797, Test Acc: 0.8805
# Epoch: 560, Train Acc: 0.8795, Test Acc: 0.8803
# Epoch: 561, Train Acc: 0.8796, Test Acc: 0.8802
# Epoch: 562, Train Acc: 0.8797, Test Acc: 0.8803
# Epoch: 563, Train Acc: 0.8797, Test Acc: 0.8806
# Epoch: 564, Train Acc: 0.8796, Test Acc: 0.8808
# Epoch: 565, Train Acc: 0.8797, Test Acc: 0.8810
# Epoch: 566, Train Acc: 0.8797, Test Acc: 0.8809
# Epoch: 567, Train Acc: 0.8797, Test Acc: 0.8809
# Epoch: 568, Train Acc: 0.8797, Test Acc: 0.8809
# Epoch: 569, Train Acc: 0.8797, Test Acc: 0.8810
# Epoch: 570, Train Acc: 0.8798, Test Acc: 0.8810
# Epoch: 571, Train Acc: 0.8798, Test Acc: 0.8810
# Epoch: 572, Train Acc: 0.8798, Test Acc: 0.8811
# Epoch: 573, Train Acc: 0.8798, Test Acc: 0.8812
# Epoch: 574, Train Acc: 0.8798, Test Acc: 0.8812
# Epoch: 575, Train Acc: 0.8798, Test Acc: 0.8812
# Epoch: 576, Train Acc: 0.8798, Test Acc: 0.8811
# Epoch: 577, Train Acc: 0.8797, Test Acc: 0.8811
# Epoch: 578, Train Acc: 0.8797, Test Acc: 0.8810
# Epoch: 579, Train Acc: 0.8797, Test Acc: 0.8810
# Epoch: 580, Train Acc: 0.8796, Test Acc: 0.8809
# Epoch: 581, Train Acc: 0.8796, Test Acc: 0.8809
# Epoch: 582, Train Acc: 0.8795, Test Acc: 0.8808
# Epoch: 583, Train Acc: 0.8795, Test Acc: 0.8807
# Epoch: 584, Train Acc: 0.8795, Test Acc: 0.8807
# Epoch: 585, Train Acc: 0.8795, Test Acc: 0.8806
# Epoch: 586, Train Acc: 0.8795, Test Acc: 0.8804
# Epoch: 587, Train Acc: 0.8795, Test Acc: 0.8802
# Epoch: 588, Train Acc: 0.8795, Test Acc: 0.8801
# Epoch: 589, Train Acc: 0.8794, Test Acc: 0.8800
# Epoch: 590, Train Acc: 0.8795, Test Acc: 0.8799
# Epoch: 591, Train Acc: 0.8794, Test Acc: 0.8799
# Epoch: 592, Train Acc: 0.8794, Test Acc: 0.8799
# Epoch: 593, Train Acc: 0.8794, Test Acc: 0.8800
# Epoch: 594, Train Acc: 0.8793, Test Acc: 0.8799
# Epoch: 595, Train Acc: 0.8792, Test Acc: 0.8796
# Epoch: 596, Train Acc: 0.8792, Test Acc: 0.8796
# Epoch: 597, Train Acc: 0.8792, Test Acc: 0.8798
# Epoch: 598, Train Acc: 0.8792, Test Acc: 0.8796
# Epoch: 599, Train Acc: 0.8793, Test Acc: 0.8798
# Epoch: 600, Train Acc: 0.8794, Test Acc: 0.8797
# Epoch: 601, Train Acc: 0.8795, Test Acc: 0.8797
# Epoch: 602, Train Acc: 0.8795, Test Acc: 0.8797
# Epoch: 603, Train Acc: 0.8795, Test Acc: 0.8796
# Epoch: 604, Train Acc: 0.8795, Test Acc: 0.8796
# Epoch: 605, Train Acc: 0.8795, Test Acc: 0.8798
# Epoch: 606, Train Acc: 0.8795, Test Acc: 0.8798
# Epoch: 607, Train Acc: 0.8795, Test Acc: 0.8799
# Epoch: 608, Train Acc: 0.8796, Test Acc: 0.8800
# Epoch: 609, Train Acc: 0.8795, Test Acc: 0.8799
# Epoch: 610, Train Acc: 0.8792, Test Acc: 0.8795
# Epoch: 611, Train Acc: 0.8792, Test Acc: 0.8796
# Epoch: 612, Train Acc: 0.8795, Test Acc: 0.8798
# Epoch: 613, Train Acc: 0.8799, Test Acc: 0.8799
# Epoch: 614, Train Acc: 0.8798, Test Acc: 0.8801
# Epoch: 615, Train Acc: 0.8798, Test Acc: 0.8806
# Epoch: 616, Train Acc: 0.8798, Test Acc: 0.8808
# Epoch: 617, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 618, Train Acc: 0.8800, Test Acc: 0.8812
# Epoch: 619, Train Acc: 0.8800, Test Acc: 0.8812
# Epoch: 620, Train Acc: 0.8800, Test Acc: 0.8812
# Epoch: 621, Train Acc: 0.8800, Test Acc: 0.8813
# Epoch: 622, Train Acc: 0.8800, Test Acc: 0.8813
# Epoch: 623, Train Acc: 0.8799, Test Acc: 0.8813
# Epoch: 624, Train Acc: 0.8800, Test Acc: 0.8812
# Epoch: 625, Train Acc: 0.8800, Test Acc: 0.8812
# Epoch: 626, Train Acc: 0.8800, Test Acc: 0.8812
# Epoch: 627, Train Acc: 0.8800, Test Acc: 0.8811
# Epoch: 628, Train Acc: 0.8800, Test Acc: 0.8811
# Epoch: 629, Train Acc: 0.8800, Test Acc: 0.8811
# Epoch: 630, Train Acc: 0.8799, Test Acc: 0.8811
# Epoch: 631, Train Acc: 0.8800, Test Acc: 0.8812
# Epoch: 632, Train Acc: 0.8799, Test Acc: 0.8812
# Epoch: 633, Train Acc: 0.8800, Test Acc: 0.8812
# Epoch: 634, Train Acc: 0.8800, Test Acc: 0.8812
# Epoch: 635, Train Acc: 0.8800, Test Acc: 0.8812
# Epoch: 636, Train Acc: 0.8800, Test Acc: 0.8812
# Epoch: 637, Train Acc: 0.8800, Test Acc: 0.8812
# Epoch: 638, Train Acc: 0.8800, Test Acc: 0.8811
# Epoch: 639, Train Acc: 0.8800, Test Acc: 0.8812
# Epoch: 640, Train Acc: 0.8800, Test Acc: 0.8811
# Epoch: 641, Train Acc: 0.8800, Test Acc: 0.8811
# Epoch: 642, Train Acc: 0.8800, Test Acc: 0.8812
# Epoch: 643, Train Acc: 0.8800, Test Acc: 0.8812
# Epoch: 644, Train Acc: 0.8800, Test Acc: 0.8812
# Epoch: 645, Train Acc: 0.8800, Test Acc: 0.8811
# Epoch: 646, Train Acc: 0.8801, Test Acc: 0.8812
# Epoch: 647, Train Acc: 0.8801, Test Acc: 0.8812
# Epoch: 648, Train Acc: 0.8801, Test Acc: 0.8812
# Epoch: 649, Train Acc: 0.8801, Test Acc: 0.8812
# Epoch: 650, Train Acc: 0.8800, Test Acc: 0.8812
# Epoch: 651, Train Acc: 0.8800, Test Acc: 0.8812
# Epoch: 652, Train Acc: 0.8800, Test Acc: 0.8812
# Epoch: 653, Train Acc: 0.8801, Test Acc: 0.8812
# Epoch: 654, Train Acc: 0.8801, Test Acc: 0.8812
# Epoch: 655, Train Acc: 0.8801, Test Acc: 0.8813
# Epoch: 656, Train Acc: 0.8801, Test Acc: 0.8814
# Epoch: 657, Train Acc: 0.8801, Test Acc: 0.8814
# Epoch: 658, Train Acc: 0.8802, Test Acc: 0.8812
# Epoch: 659, Train Acc: 0.8801, Test Acc: 0.8812
# Epoch: 660, Train Acc: 0.8802, Test Acc: 0.8813
# Epoch: 661, Train Acc: 0.8803, Test Acc: 0.8814
# Epoch: 662, Train Acc: 0.8804, Test Acc: 0.8815
# Epoch: 663, Train Acc: 0.8805, Test Acc: 0.8816
# Epoch: 664, Train Acc: 0.8805, Test Acc: 0.8816
# Epoch: 665, Train Acc: 0.8804, Test Acc: 0.8815
# Epoch: 666, Train Acc: 0.8803, Test Acc: 0.8815
# Epoch: 667, Train Acc: 0.8803, Test Acc: 0.8815
# Epoch: 668, Train Acc: 0.8803, Test Acc: 0.8814
# Epoch: 669, Train Acc: 0.8802, Test Acc: 0.8812
# Epoch: 670, Train Acc: 0.8797, Test Acc: 0.8796
# Epoch: 671, Train Acc: 0.8749, Test Acc: 0.8753
# Epoch: 672, Train Acc: 0.8747, Test Acc: 0.8749
# Epoch: 673, Train Acc: 0.8797, Test Acc: 0.8796
# Epoch: 674, Train Acc: 0.8803, Test Acc: 0.8815
# Epoch: 675, Train Acc: 0.8804, Test Acc: 0.8814
# Epoch: 676, Train Acc: 0.8801, Test Acc: 0.8812
# Epoch: 677, Train Acc: 0.8802, Test Acc: 0.8814
# Epoch: 678, Train Acc: 0.8801, Test Acc: 0.8814
# Epoch: 679, Train Acc: 0.8801, Test Acc: 0.8813
# Epoch: 680, Train Acc: 0.8801, Test Acc: 0.8812
# Epoch: 681, Train Acc: 0.8802, Test Acc: 0.8812
# Epoch: 682, Train Acc: 0.8802, Test Acc: 0.8812
# Epoch: 683, Train Acc: 0.8802, Test Acc: 0.8812
# Epoch: 684, Train Acc: 0.8802, Test Acc: 0.8812
# Epoch: 685, Train Acc: 0.8802, Test Acc: 0.8812
# Epoch: 686, Train Acc: 0.8802, Test Acc: 0.8812
# Epoch: 687, Train Acc: 0.8801, Test Acc: 0.8812
# Epoch: 688, Train Acc: 0.8800, Test Acc: 0.8811
# Epoch: 689, Train Acc: 0.8801, Test Acc: 0.8810
# Epoch: 690, Train Acc: 0.8801, Test Acc: 0.8811
# Epoch: 691, Train Acc: 0.8801, Test Acc: 0.8811
# Epoch: 692, Train Acc: 0.8801, Test Acc: 0.8811
# Epoch: 693, Train Acc: 0.8800, Test Acc: 0.8811
# Epoch: 694, Train Acc: 0.8800, Test Acc: 0.8812
# Epoch: 695, Train Acc: 0.8800, Test Acc: 0.8811
# Epoch: 696, Train Acc: 0.8800, Test Acc: 0.8810
# Epoch: 697, Train Acc: 0.8800, Test Acc: 0.8810
# Epoch: 698, Train Acc: 0.8800, Test Acc: 0.8810
# Epoch: 699, Train Acc: 0.8800, Test Acc: 0.8810
# Epoch: 700, Train Acc: 0.8800, Test Acc: 0.8810
# Epoch: 701, Train Acc: 0.8800, Test Acc: 0.8810
# Epoch: 702, Train Acc: 0.8800, Test Acc: 0.8810
# Epoch: 703, Train Acc: 0.8800, Test Acc: 0.8810
# Epoch: 704, Train Acc: 0.8800, Test Acc: 0.8810
# Epoch: 705, Train Acc: 0.8800, Test Acc: 0.8810
# Epoch: 706, Train Acc: 0.8800, Test Acc: 0.8809
# Epoch: 707, Train Acc: 0.8800, Test Acc: 0.8809
# Epoch: 708, Train Acc: 0.8800, Test Acc: 0.8809
# Epoch: 709, Train Acc: 0.8800, Test Acc: 0.8809
# Epoch: 710, Train Acc: 0.8800, Test Acc: 0.8810
# Epoch: 711, Train Acc: 0.8800, Test Acc: 0.8811
# Epoch: 712, Train Acc: 0.8800, Test Acc: 0.8811
# Epoch: 713, Train Acc: 0.8800, Test Acc: 0.8811
# Epoch: 714, Train Acc: 0.8800, Test Acc: 0.8811
# Epoch: 715, Train Acc: 0.8801, Test Acc: 0.8810
# Epoch: 716, Train Acc: 0.8801, Test Acc: 0.8810
# Epoch: 717, Train Acc: 0.8800, Test Acc: 0.8810
# Epoch: 718, Train Acc: 0.8800, Test Acc: 0.8812
# Epoch: 719, Train Acc: 0.8799, Test Acc: 0.8812
# Epoch: 720, Train Acc: 0.8798, Test Acc: 0.8812
# Epoch: 721, Train Acc: 0.8799, Test Acc: 0.8812
# Epoch: 722, Train Acc: 0.8798, Test Acc: 0.8811
# Epoch: 723, Train Acc: 0.8799, Test Acc: 0.8811
# Epoch: 724, Train Acc: 0.8800, Test Acc: 0.8811
# Epoch: 725, Train Acc: 0.8800, Test Acc: 0.8811
# Epoch: 726, Train Acc: 0.8800, Test Acc: 0.8810
# Epoch: 727, Train Acc: 0.8799, Test Acc: 0.8808
# Epoch: 728, Train Acc: 0.8797, Test Acc: 0.8808
# Epoch: 729, Train Acc: 0.8796, Test Acc: 0.8807
# Epoch: 730, Train Acc: 0.8796, Test Acc: 0.8805
# Epoch: 731, Train Acc: 0.8797, Test Acc: 0.8805
# Epoch: 732, Train Acc: 0.8796, Test Acc: 0.8804
# Epoch: 733, Train Acc: 0.8797, Test Acc: 0.8803
# Epoch: 734, Train Acc: 0.8796, Test Acc: 0.8802
# Epoch: 735, Train Acc: 0.8797, Test Acc: 0.8799
# Epoch: 736, Train Acc: 0.8796, Test Acc: 0.8797
# Epoch: 737, Train Acc: 0.8796, Test Acc: 0.8798
# Epoch: 738, Train Acc: 0.8796, Test Acc: 0.8798
# Epoch: 739, Train Acc: 0.8796, Test Acc: 0.8797
# Epoch: 740, Train Acc: 0.8796, Test Acc: 0.8798
# Epoch: 741, Train Acc: 0.8795, Test Acc: 0.8800
# Epoch: 742, Train Acc: 0.8790, Test Acc: 0.8801
# Epoch: 743, Train Acc: 0.8789, Test Acc: 0.8799
# Epoch: 744, Train Acc: 0.8780, Test Acc: 0.8782
# Epoch: 745, Train Acc: 0.8765, Test Acc: 0.8774
# Epoch: 746, Train Acc: 0.8745, Test Acc: 0.8754
# Epoch: 747, Train Acc: 0.8730, Test Acc: 0.8740
# Epoch: 748, Train Acc: 0.8726, Test Acc: 0.8734
# Epoch: 749, Train Acc: 0.8738, Test Acc: 0.8749
# Epoch: 750, Train Acc: 0.8752, Test Acc: 0.8769
# Epoch: 751, Train Acc: 0.8779, Test Acc: 0.8781
# Epoch: 752, Train Acc: 0.8792, Test Acc: 0.8792
# Epoch: 753, Train Acc: 0.8797, Test Acc: 0.8801
# Epoch: 754, Train Acc: 0.8798, Test Acc: 0.8810
# Epoch: 755, Train Acc: 0.8799, Test Acc: 0.8812
# Epoch: 756, Train Acc: 0.8800, Test Acc: 0.8812
# Epoch: 757, Train Acc: 0.8800, Test Acc: 0.8811
# Epoch: 758, Train Acc: 0.8800, Test Acc: 0.8810
# Epoch: 759, Train Acc: 0.8800, Test Acc: 0.8812
# Epoch: 760, Train Acc: 0.8800, Test Acc: 0.8812
# Epoch: 761, Train Acc: 0.8799, Test Acc: 0.8812
# Epoch: 762, Train Acc: 0.8799, Test Acc: 0.8811
# Epoch: 763, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 764, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 765, Train Acc: 0.8798, Test Acc: 0.8810
# Epoch: 766, Train Acc: 0.8798, Test Acc: 0.8810
# Epoch: 767, Train Acc: 0.8798, Test Acc: 0.8810
# Epoch: 768, Train Acc: 0.8798, Test Acc: 0.8810
# Epoch: 769, Train Acc: 0.8798, Test Acc: 0.8810
# Epoch: 770, Train Acc: 0.8798, Test Acc: 0.8810
# Epoch: 771, Train Acc: 0.8798, Test Acc: 0.8810
# Epoch: 772, Train Acc: 0.8798, Test Acc: 0.8810
# Epoch: 773, Train Acc: 0.8798, Test Acc: 0.8810
# Epoch: 774, Train Acc: 0.8798, Test Acc: 0.8810
# Epoch: 775, Train Acc: 0.8798, Test Acc: 0.8810
# Epoch: 776, Train Acc: 0.8798, Test Acc: 0.8810
# Epoch: 777, Train Acc: 0.8798, Test Acc: 0.8810
# Epoch: 778, Train Acc: 0.8798, Test Acc: 0.8810
# Epoch: 779, Train Acc: 0.8798, Test Acc: 0.8810
# Epoch: 780, Train Acc: 0.8798, Test Acc: 0.8810
# Epoch: 781, Train Acc: 0.8798, Test Acc: 0.8810
# Epoch: 782, Train Acc: 0.8798, Test Acc: 0.8810
# Epoch: 783, Train Acc: 0.8798, Test Acc: 0.8810
# Epoch: 784, Train Acc: 0.8798, Test Acc: 0.8810
# Epoch: 785, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 786, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 787, Train Acc: 0.8799, Test Acc: 0.8810
# Epoch: 788, Train Acc: 0.8800, Test Acc: 0.8811
# Epoch: 789, Train Acc: 0.8800, Test Acc: 0.8812
# Epoch: 790, Train Acc: 0.8800, Test Acc: 0.8812
# Epoch: 791, Train Acc: 0.8800, Test Acc: 0.8814
# Epoch: 792, Train Acc: 0.8800, Test Acc: 0.8814
# Epoch: 793, Train Acc: 0.8800, Test Acc: 0.8813
# Epoch: 794, Train Acc: 0.8800, Test Acc: 0.8813
# Epoch: 795, Train Acc: 0.8800, Test Acc: 0.8813
# Epoch: 796, Train Acc: 0.8800, Test Acc: 0.8813
# Epoch: 797, Train Acc: 0.8801, Test Acc: 0.8813
# Epoch: 798, Train Acc: 0.8801, Test Acc: 0.8812
# Epoch: 799, Train Acc: 0.8801, Test Acc: 0.8812
# Epoch: 800, Train Acc: 0.8801, Test Acc: 0.8813
# Epoch: 801, Train Acc: 0.8801, Test Acc: 0.8812
# Epoch: 802, Train Acc: 0.8801, Test Acc: 0.8812
# Epoch: 803, Train Acc: 0.8801, Test Acc: 0.8812
# Epoch: 804, Train Acc: 0.8801, Test Acc: 0.8812
# Epoch: 805, Train Acc: 0.8800, Test Acc: 0.8812
# Epoch: 806, Train Acc: 0.8800, Test Acc: 0.8812
# Epoch: 807, Train Acc: 0.8800, Test Acc: 0.8812
# Epoch: 808, Train Acc: 0.8800, Test Acc: 0.8812
# Epoch: 809, Train Acc: 0.8800, Test Acc: 0.8812
# Epoch: 810, Train Acc: 0.8800, Test Acc: 0.8812
# Epoch: 811, Train Acc: 0.8800, Test Acc: 0.8811
# Epoch: 812, Train Acc: 0.8800, Test Acc: 0.8811
# Epoch: 813, Train Acc: 0.8800, Test Acc: 0.8812
# Epoch: 814, Train Acc: 0.8800, Test Acc: 0.8812
# Epoch: 815, Train Acc: 0.8801, Test Acc: 0.8813
# Epoch: 816, Train Acc: 0.8801, Test Acc: 0.8813
# Epoch: 817, Train Acc: 0.8801, Test Acc: 0.8812
# Epoch: 818, Train Acc: 0.8801, Test Acc: 0.8811
# Epoch: 819, Train Acc: 0.8801, Test Acc: 0.8810
# Epoch: 820, Train Acc: 0.8802, Test Acc: 0.8811
# Epoch: 821, Train Acc: 0.8803, Test Acc: 0.8813
# Epoch: 822, Train Acc: 0.8803, Test Acc: 0.8815
# Epoch: 823, Train Acc: 0.8803, Test Acc: 0.8817
# Epoch: 824, Train Acc: 0.8803, Test Acc: 0.8817
# Epoch: 825, Train Acc: 0.8803, Test Acc: 0.8815
# Epoch: 826, Train Acc: 0.8803, Test Acc: 0.8815
# Epoch: 827, Train Acc: 0.8803, Test Acc: 0.8816
# Epoch: 828, Train Acc: 0.8802, Test Acc: 0.8818
# Epoch: 829, Train Acc: 0.8802, Test Acc: 0.8813
# Epoch: 830, Train Acc: 0.8802, Test Acc: 0.8810
# Epoch: 831, Train Acc: 0.8800, Test Acc: 0.8808
# Epoch: 832, Train Acc: 0.8800, Test Acc: 0.8803
# Epoch: 833, Train Acc: 0.8798, Test Acc: 0.8804
# Epoch: 834, Train Acc: 0.8797, Test Acc: 0.8801
# Epoch: 835, Train Acc: 0.8796, Test Acc: 0.8800
# Epoch: 836, Train Acc: 0.8795, Test Acc: 0.8801
# Epoch: 837, Train Acc: 0.8794, Test Acc: 0.8800
# Epoch: 838, Train Acc: 0.8794, Test Acc: 0.8803
# Epoch: 839, Train Acc: 0.8793, Test Acc: 0.8803
# Epoch: 840, Train Acc: 0.8792, Test Acc: 0.8803
# Epoch: 841, Train Acc: 0.8796, Test Acc: 0.8802
# Epoch: 842, Train Acc: 0.8800, Test Acc: 0.8807
# Epoch: 843, Train Acc: 0.8803, Test Acc: 0.8810
# Epoch: 844, Train Acc: 0.8803, Test Acc: 0.8816
# Epoch: 845, Train Acc: 0.8805, Test Acc: 0.8819
# Epoch: 846, Train Acc: 0.8806, Test Acc: 0.8820
# Epoch: 847, Train Acc: 0.8805, Test Acc: 0.8817
# Epoch: 848, Train Acc: 0.8804, Test Acc: 0.8817
# Epoch: 849, Train Acc: 0.8804, Test Acc: 0.8816
# Epoch: 850, Train Acc: 0.8804, Test Acc: 0.8815
# Epoch: 851, Train Acc: 0.8804, Test Acc: 0.8815
# Epoch: 852, Train Acc: 0.8804, Test Acc: 0.8815
# Epoch: 853, Train Acc: 0.8804, Test Acc: 0.8815
# Epoch: 854, Train Acc: 0.8804, Test Acc: 0.8817
# Epoch: 855, Train Acc: 0.8804, Test Acc: 0.8818
# Epoch: 856, Train Acc: 0.8804, Test Acc: 0.8817
# Epoch: 857, Train Acc: 0.8805, Test Acc: 0.8817
# Epoch: 858, Train Acc: 0.8805, Test Acc: 0.8817
# Epoch: 859, Train Acc: 0.8805, Test Acc: 0.8818
# Epoch: 860, Train Acc: 0.8805, Test Acc: 0.8818
# Epoch: 861, Train Acc: 0.8805, Test Acc: 0.8818
# Epoch: 862, Train Acc: 0.8805, Test Acc: 0.8818
# Epoch: 863, Train Acc: 0.8805, Test Acc: 0.8817
# Epoch: 864, Train Acc: 0.8804, Test Acc: 0.8817
# Epoch: 865, Train Acc: 0.8804, Test Acc: 0.8817
# Epoch: 866, Train Acc: 0.8804, Test Acc: 0.8817
# Epoch: 867, Train Acc: 0.8804, Test Acc: 0.8819
# Epoch: 868, Train Acc: 0.8804, Test Acc: 0.8819
# Epoch: 869, Train Acc: 0.8804, Test Acc: 0.8818
# Epoch: 870, Train Acc: 0.8804, Test Acc: 0.8818
# Epoch: 871, Train Acc: 0.8805, Test Acc: 0.8819
# Epoch: 872, Train Acc: 0.8806, Test Acc: 0.8819
# Epoch: 873, Train Acc: 0.8807, Test Acc: 0.8819
# Epoch: 874, Train Acc: 0.8807, Test Acc: 0.8821
# Epoch: 875, Train Acc: 0.8807, Test Acc: 0.8821
# Epoch: 876, Train Acc: 0.8807, Test Acc: 0.8822
# Epoch: 877, Train Acc: 0.8807, Test Acc: 0.8822
# Epoch: 878, Train Acc: 0.8806, Test Acc: 0.8821
# Epoch: 879, Train Acc: 0.8806, Test Acc: 0.8819
# Epoch: 880, Train Acc: 0.8805, Test Acc: 0.8819
# Epoch: 881, Train Acc: 0.8804, Test Acc: 0.8815
# Epoch: 882, Train Acc: 0.8804, Test Acc: 0.8815
# Epoch: 883, Train Acc: 0.8804, Test Acc: 0.8815
# Epoch: 884, Train Acc: 0.8804, Test Acc: 0.8814
# Epoch: 885, Train Acc: 0.8804, Test Acc: 0.8815
# Epoch: 886, Train Acc: 0.8804, Test Acc: 0.8815
# Epoch: 887, Train Acc: 0.8804, Test Acc: 0.8815
# Epoch: 888, Train Acc: 0.8804, Test Acc: 0.8815
# Epoch: 889, Train Acc: 0.8804, Test Acc: 0.8815
# Epoch: 890, Train Acc: 0.8803, Test Acc: 0.8815
# Epoch: 891, Train Acc: 0.8804, Test Acc: 0.8815
# Epoch: 892, Train Acc: 0.8803, Test Acc: 0.8814
# Epoch: 893, Train Acc: 0.8801, Test Acc: 0.8814
# Epoch: 894, Train Acc: 0.8803, Test Acc: 0.8815
# Epoch: 895, Train Acc: 0.8802, Test Acc: 0.8817
# Epoch: 896, Train Acc: 0.8803, Test Acc: 0.8815
# Epoch: 897, Train Acc: 0.8803, Test Acc: 0.8815
# Epoch: 898, Train Acc: 0.8803, Test Acc: 0.8815
# Epoch: 899, Train Acc: 0.8803, Test Acc: 0.8815
# Epoch: 900, Train Acc: 0.8803, Test Acc: 0.8815
# Epoch: 901, Train Acc: 0.8803, Test Acc: 0.8814
# Epoch: 902, Train Acc: 0.8802, Test Acc: 0.8812
# Epoch: 903, Train Acc: 0.8802, Test Acc: 0.8812
# Epoch: 904, Train Acc: 0.8802, Test Acc: 0.8812
# Epoch: 905, Train Acc: 0.8801, Test Acc: 0.8812
# Epoch: 906, Train Acc: 0.8801, Test Acc: 0.8812
# Epoch: 907, Train Acc: 0.8800, Test Acc: 0.8812
# Epoch: 908, Train Acc: 0.8800, Test Acc: 0.8812
# Epoch: 909, Train Acc: 0.8800, Test Acc: 0.8812
# Epoch: 910, Train Acc: 0.8800, Test Acc: 0.8813
# Epoch: 911, Train Acc: 0.8800, Test Acc: 0.8813
# Epoch: 912, Train Acc: 0.8800, Test Acc: 0.8812
# Epoch: 913, Train Acc: 0.8801, Test Acc: 0.8812
# Epoch: 914, Train Acc: 0.8801, Test Acc: 0.8812
# Epoch: 915, Train Acc: 0.8801, Test Acc: 0.8812
# Epoch: 916, Train Acc: 0.8801, Test Acc: 0.8812
# Epoch: 917, Train Acc: 0.8802, Test Acc: 0.8812
# Epoch: 918, Train Acc: 0.8802, Test Acc: 0.8811
# Epoch: 919, Train Acc: 0.8803, Test Acc: 0.8812
# Epoch: 920, Train Acc: 0.8802, Test Acc: 0.8814
# Epoch: 921, Train Acc: 0.8801, Test Acc: 0.8814
# Epoch: 922, Train Acc: 0.8801, Test Acc: 0.8815
# Epoch: 923, Train Acc: 0.8802, Test Acc: 0.8815
# Epoch: 924, Train Acc: 0.8802, Test Acc: 0.8815
# Epoch: 925, Train Acc: 0.8802, Test Acc: 0.8815
# Epoch: 926, Train Acc: 0.8802, Test Acc: 0.8815
# Epoch: 927, Train Acc: 0.8802, Test Acc: 0.8815
# Epoch: 928, Train Acc: 0.8802, Test Acc: 0.8815
# Epoch: 929, Train Acc: 0.8802, Test Acc: 0.8816
# Epoch: 930, Train Acc: 0.8802, Test Acc: 0.8815
# Epoch: 931, Train Acc: 0.8803, Test Acc: 0.8814
# Epoch: 932, Train Acc: 0.8802, Test Acc: 0.8812
# Epoch: 933, Train Acc: 0.8803, Test Acc: 0.8811
# Epoch: 934, Train Acc: 0.8803, Test Acc: 0.8812
# Epoch: 935, Train Acc: 0.8803, Test Acc: 0.8812
# Epoch: 936, Train Acc: 0.8803, Test Acc: 0.8813
# Epoch: 937, Train Acc: 0.8803, Test Acc: 0.8814
# Epoch: 938, Train Acc: 0.8803, Test Acc: 0.8813
# Epoch: 939, Train Acc: 0.8803, Test Acc: 0.8812
# Epoch: 940, Train Acc: 0.8803, Test Acc: 0.8813
# Epoch: 941, Train Acc: 0.8803, Test Acc: 0.8812
# Epoch: 942, Train Acc: 0.8803, Test Acc: 0.8812
# Epoch: 943, Train Acc: 0.8802, Test Acc: 0.8812
# Epoch: 944, Train Acc: 0.8802, Test Acc: 0.8814
# Epoch: 945, Train Acc: 0.8803, Test Acc: 0.8815
# Epoch: 946, Train Acc: 0.8803, Test Acc: 0.8814
# Epoch: 947, Train Acc: 0.8803, Test Acc: 0.8815
# Epoch: 948, Train Acc: 0.8802, Test Acc: 0.8815
# Epoch: 949, Train Acc: 0.8803, Test Acc: 0.8815
# Epoch: 950, Train Acc: 0.8803, Test Acc: 0.8815
# Epoch: 951, Train Acc: 0.8804, Test Acc: 0.8812
# Epoch: 952, Train Acc: 0.8803, Test Acc: 0.8814
# Epoch: 953, Train Acc: 0.8802, Test Acc: 0.8814
# Epoch: 954, Train Acc: 0.8802, Test Acc: 0.8812
# Epoch: 955, Train Acc: 0.8802, Test Acc: 0.8812
# Epoch: 956, Train Acc: 0.8802, Test Acc: 0.8812
# Epoch: 957, Train Acc: 0.8802, Test Acc: 0.8812
# Epoch: 958, Train Acc: 0.8801, Test Acc: 0.8812
# Epoch: 959, Train Acc: 0.8802, Test Acc: 0.8814
# Epoch: 960, Train Acc: 0.8802, Test Acc: 0.8814
# Epoch: 961, Train Acc: 0.8801, Test Acc: 0.8814
# Epoch: 962, Train Acc: 0.8801, Test Acc: 0.8814
# Epoch: 963, Train Acc: 0.8801, Test Acc: 0.8814
# Epoch: 964, Train Acc: 0.8801, Test Acc: 0.8814
# Epoch: 965, Train Acc: 0.8801, Test Acc: 0.8814
# Epoch: 966, Train Acc: 0.8801, Test Acc: 0.8814
# Epoch: 967, Train Acc: 0.8801, Test Acc: 0.8814
# Epoch: 968, Train Acc: 0.8802, Test Acc: 0.8814
# Epoch: 969, Train Acc: 0.8802, Test Acc: 0.8813
# Epoch: 970, Train Acc: 0.8802, Test Acc: 0.8813
# Epoch: 971, Train Acc: 0.8802, Test Acc: 0.8814
# Epoch: 972, Train Acc: 0.8802, Test Acc: 0.8814
# Epoch: 973, Train Acc: 0.8803, Test Acc: 0.8814
# Epoch: 974, Train Acc: 0.8803, Test Acc: 0.8814
# Epoch: 975, Train Acc: 0.8803, Test Acc: 0.8813
# Epoch: 976, Train Acc: 0.8804, Test Acc: 0.8814
# Epoch: 977, Train Acc: 0.8804, Test Acc: 0.8814
# Epoch: 978, Train Acc: 0.8804, Test Acc: 0.8814
# Epoch: 979, Train Acc: 0.8805, Test Acc: 0.8815
# Epoch: 980, Train Acc: 0.8805, Test Acc: 0.8815
# Epoch: 981, Train Acc: 0.8806, Test Acc: 0.8817
# Epoch: 982, Train Acc: 0.8806, Test Acc: 0.8818
# Epoch: 983, Train Acc: 0.8806, Test Acc: 0.8819
# Epoch: 984, Train Acc: 0.8806, Test Acc: 0.8820
# Epoch: 985, Train Acc: 0.8808, Test Acc: 0.8822
# Epoch: 986, Train Acc: 0.8807, Test Acc: 0.8821
# Epoch: 987, Train Acc: 0.8806, Test Acc: 0.8819
# Epoch: 988, Train Acc: 0.8806, Test Acc: 0.8819
# Epoch: 989, Train Acc: 0.8806, Test Acc: 0.8818
# Epoch: 990, Train Acc: 0.8805, Test Acc: 0.8817
# Epoch: 991, Train Acc: 0.8805, Test Acc: 0.8815
# Epoch: 992, Train Acc: 0.8805, Test Acc: 0.8816
# Epoch: 993, Train Acc: 0.8805, Test Acc: 0.8816
# Epoch: 994, Train Acc: 0.8804, Test Acc: 0.8816
# Epoch: 995, Train Acc: 0.8805, Test Acc: 0.8817
# Epoch: 996, Train Acc: 0.8806, Test Acc: 0.8819
# Epoch: 997, Train Acc: 0.8807, Test Acc: 0.8819
# Epoch: 998, Train Acc: 0.8808, Test Acc: 0.8821
# Epoch: 999, Train Acc: 0.8808, Test Acc: 0.8823
# Epoch: 1000, Train Acc: 0.8807, Test Acc: 0.8823
# Epoch: 1001, Train Acc: 0.8807, Test Acc: 0.8825
# Epoch: 1002, Train Acc: 0.8808, Test Acc: 0.8823
# Epoch: 1003, Train Acc: 0.8808, Test Acc: 0.8824
# Epoch: 1004, Train Acc: 0.8807, Test Acc: 0.8823
# Epoch: 1005, Train Acc: 0.8807, Test Acc: 0.8823
# Epoch: 1006, Train Acc: 0.8807, Test Acc: 0.8824
# Epoch: 1007, Train Acc: 0.8807, Test Acc: 0.8824
# Epoch: 1008, Train Acc: 0.8808, Test Acc: 0.8824
# Epoch: 1009, Train Acc: 0.8808, Test Acc: 0.8824
# Epoch: 1010, Train Acc: 0.8808, Test Acc: 0.8825
# Epoch: 1011, Train Acc: 0.8808, Test Acc: 0.8826
# Epoch: 1012, Train Acc: 0.8808, Test Acc: 0.8824
# Epoch: 1013, Train Acc: 0.8808, Test Acc: 0.8828
# Epoch: 1014, Train Acc: 0.8808, Test Acc: 0.8827
# Epoch: 1015, Train Acc: 0.8809, Test Acc: 0.8824
# Epoch: 1016, Train Acc: 0.8809, Test Acc: 0.8825
# Epoch: 1017, Train Acc: 0.8809, Test Acc: 0.8825
# Epoch: 1018, Train Acc: 0.8809, Test Acc: 0.8825
# Epoch: 1019, Train Acc: 0.8809, Test Acc: 0.8825
# Epoch: 1020, Train Acc: 0.8809, Test Acc: 0.8825
# Epoch: 1021, Train Acc: 0.8809, Test Acc: 0.8826
# Epoch: 1022, Train Acc: 0.8809, Test Acc: 0.8827
# Epoch: 1023, Train Acc: 0.8809, Test Acc: 0.8827
# Epoch: 1024, Train Acc: 0.8809, Test Acc: 0.8828
# Epoch: 1025, Train Acc: 0.8808, Test Acc: 0.8828
# Epoch: 1026, Train Acc: 0.8809, Test Acc: 0.8828
# Epoch: 1027, Train Acc: 0.8809, Test Acc: 0.8828
# Epoch: 1028, Train Acc: 0.8809, Test Acc: 0.8828
# Epoch: 1029, Train Acc: 0.8809, Test Acc: 0.8828
# Epoch: 1030, Train Acc: 0.8809, Test Acc: 0.8828
# Epoch: 1031, Train Acc: 0.8809, Test Acc: 0.8828
# Epoch: 1032, Train Acc: 0.8809, Test Acc: 0.8828
# Epoch: 1033, Train Acc: 0.8809, Test Acc: 0.8828
# Epoch: 1034, Train Acc: 0.8809, Test Acc: 0.8826
# Epoch: 1035, Train Acc: 0.8810, Test Acc: 0.8825
# Epoch: 1036, Train Acc: 0.8810, Test Acc: 0.8826
# Epoch: 1037, Train Acc: 0.8809, Test Acc: 0.8826
# Epoch: 1038, Train Acc: 0.8810, Test Acc: 0.8825
# Epoch: 1039, Train Acc: 0.8811, Test Acc: 0.8824
# Epoch: 1040, Train Acc: 0.8811, Test Acc: 0.8823
# Epoch: 1041, Train Acc: 0.8810, Test Acc: 0.8823
# Epoch: 1042, Train Acc: 0.8810, Test Acc: 0.8824
# Epoch: 1043, Train Acc: 0.8809, Test Acc: 0.8828
# Epoch: 1044, Train Acc: 0.8810, Test Acc: 0.8828
# Epoch: 1045, Train Acc: 0.8812, Test Acc: 0.8826
# Epoch: 1046, Train Acc: 0.8811, Test Acc: 0.8826
# Epoch: 1047, Train Acc: 0.8811, Test Acc: 0.8825
# Epoch: 1048, Train Acc: 0.8812, Test Acc: 0.8826
# Epoch: 1049, Train Acc: 0.8810, Test Acc: 0.8828
# Epoch: 1050, Train Acc: 0.8810, Test Acc: 0.8827
# Epoch: 1051, Train Acc: 0.8810, Test Acc: 0.8826
# Epoch: 1052, Train Acc: 0.8810, Test Acc: 0.8826
# Epoch: 1053, Train Acc: 0.8809, Test Acc: 0.8826
# Epoch: 1054, Train Acc: 0.8810, Test Acc: 0.8826
# Epoch: 1055, Train Acc: 0.8810, Test Acc: 0.8826
# Epoch: 1056, Train Acc: 0.8811, Test Acc: 0.8827
# Epoch: 1057, Train Acc: 0.8810, Test Acc: 0.8828
# Epoch: 1058, Train Acc: 0.8808, Test Acc: 0.8826
# Epoch: 1059, Train Acc: 0.8797, Test Acc: 0.8812
# Epoch: 1060, Train Acc: 0.8800, Test Acc: 0.8814
# Epoch: 1061, Train Acc: 0.8810, Test Acc: 0.8828
# Epoch: 1062, Train Acc: 0.8812, Test Acc: 0.8826
# Epoch: 1063, Train Acc: 0.8810, Test Acc: 0.8826
# Epoch: 1064, Train Acc: 0.8809, Test Acc: 0.8824
# Epoch: 1065, Train Acc: 0.8806, Test Acc: 0.8821
# Epoch: 1066, Train Acc: 0.8805, Test Acc: 0.8817
# Epoch: 1067, Train Acc: 0.8804, Test Acc: 0.8815
# Epoch: 1068, Train Acc: 0.8804, Test Acc: 0.8816
# Epoch: 1069, Train Acc: 0.8804, Test Acc: 0.8815
# Epoch: 1070, Train Acc: 0.8803, Test Acc: 0.8814
# Epoch: 1071, Train Acc: 0.8802, Test Acc: 0.8814
# Epoch: 1072, Train Acc: 0.8802, Test Acc: 0.8814
# Epoch: 1073, Train Acc: 0.8802, Test Acc: 0.8814
# Epoch: 1074, Train Acc: 0.8802, Test Acc: 0.8814
# Epoch: 1075, Train Acc: 0.8802, Test Acc: 0.8814
# Epoch: 1076, Train Acc: 0.8802, Test Acc: 0.8814
# Epoch: 1077, Train Acc: 0.8802, Test Acc: 0.8814
# Epoch: 1078, Train Acc: 0.8802, Test Acc: 0.8814
# Epoch: 1079, Train Acc: 0.8802, Test Acc: 0.8814
# Epoch: 1080, Train Acc: 0.8802, Test Acc: 0.8814
# Epoch: 1081, Train Acc: 0.8802, Test Acc: 0.8814
# Epoch: 1082, Train Acc: 0.8802, Test Acc: 0.8814
# Epoch: 1083, Train Acc: 0.8803, Test Acc: 0.8814
# Epoch: 1084, Train Acc: 0.8803, Test Acc: 0.8814
# Epoch: 1085, Train Acc: 0.8803, Test Acc: 0.8814
# Epoch: 1086, Train Acc: 0.8803, Test Acc: 0.8815
# Epoch: 1087, Train Acc: 0.8803, Test Acc: 0.8815
# Epoch: 1088, Train Acc: 0.8804, Test Acc: 0.8816

# %%
print("Train Accuracy percentage : ",train_accuracy[epoch-1]*100)
print("Test Accuracy percentage : ",test_accuracy[epoch-1]*100)
# Out:
# Train Accuracy percentage :  67.42424242424242
# Test Accuracy percentage :  62.99879081015719

# %%
#@title EpochVSError Plot
x_axis = [i for i in range(1,epoch+1)]
plt.plot(x_axis , train_losses, label='train_error')
plt.legend()
plt.xlabel("Epcohs")
plt.ylabel("Error")
plt.savefig('NCI109_errorVSepoch.png')
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x_axis, train_accuracy, 'b', label='Training Accuracy')
ax.plot(x_axis, test_accuracy, 'r', label='Test Accuracy')
ax.set_xlabel('Epochs')
ax.set_ylabel('Accuracy')
ax.set_title('Training Accuracy vs Test Accuracy')
ax.legend()
plt.savefig('NCI109_TrainAccVSTestAcc.png')
plt.show()

# %% [markdown]
# As one can see, our model reaches around **76% test accuracy**.
# Reasons for the fluctations in accuracy can be explained by the rather small dataset (only 38 test graphs), and usually disappear once one applies GNNs to larger datasets.

# %% [markdown]
# ## (Optional) Exercise
#
# Can we do better than this?
# As multiple papers pointed out ([Xu et al. (2018)](https://arxiv.org/abs/1810.00826), [Morris et al. (2018)](https://arxiv.org/abs/1810.02244)), applying **neighborhood normalization decreases the expressivity of GNNs in distinguishing certain graph structures**.
# An alternative formulation ([Morris et al. (2018)](https://arxiv.org/abs/1810.02244)) omits neighborhood normalization completely and adds a simple skip-connection to the GNN layer in order to preserve central node information:
#
# $$
# \mathbf{x}_v^{(\ell+1)} = \mathbf{W}^{(\ell + 1)}_1 \mathbf{x}_v^{(\ell)} + \mathbf{W}^{(\ell + 1)}_2 \sum_{w \in \mathcal{N}(v)} \mathbf{x}_w^{(\ell)}
# $$
#
# This layer is implemented under the name [`GraphConv`](https://pytorch-geometric.readthedocs.io/en/latest/modules/nn.html#torch_geometric.nn.conv.GraphConv) in PyTorch Geometric.
#
# As an exercise, you are invited to complete the following code to the extent that it makes use of PyG's `GraphConv` rather than `GCNConv`.
# This should bring you close to **82% test accuracy**.

# %%
from torch_geometric.nn import GraphConv


class GNN(torch.nn.Module):
    def __init__(self, hidden_channels):
        super(GNN, self).__init__()
        torch.manual_seed(12345)
        self.conv1 = ...  # TODO
        self.conv2 = ...  # TODO
        self.conv3 = ...  # TODO
        self.lin = Linear(hidden_channels, dataset.num_classes)

    def forward(self, x, edge_index, batch):
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = self.conv2(x, edge_index)
        x = x.relu()
        x = self.conv3(x, edge_index)

        x = global_mean_pool(x, batch)

        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin(x)
        
        return x

model = GNN(hidden_channels=64)
print(model)

# %%
from IPython.display import Javascript
display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 300})'''))

model = GNN(hidden_channels=64)
print(model)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

for epoch in range(1, 201):
    train()
    train_acc = test(train_loader)
    test_acc = test(test_loader)
    print(f'Epoch: {epoch:03d}, Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}')

# %% [markdown]
# ## Conclusion
#
# In this chapter, you have learned how to apply GNNs to the task of graph classification.
# You have learned how graphs can be batched together for better GPU utilization, and how to apply readout layers for obtaining graph embeddings rather than node embeddings.
#
# In the next session, you will learn how you can utilize PyTorch Geometric to let Graph Neural Networks scale to single large graphs.
#
# [Next: Scaling Graph Neural Networks](https://colab.research.google.com/drive/1XAjcjRHrSR_ypCk_feIWFbcBKyT4Lirs)
